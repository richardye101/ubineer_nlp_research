# %%
import sys
sys.path.insert(0, '..')
# %load_ext autoreload
# %autoreload 2
# %aimport std_func

# Hide warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 get_ipython().run_line_magic('load_ext', 'autoreload')
#       4 get_ipython().run_line_magic('autoreload', '2')
# ----> 5 get_ipython().run_line_magic('aimport', 'std_func')
#       7 # Hide warnings
#       8 import warnings
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2294, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2292     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2293 with self.builtin_trap:
# -> 2294     result = fn(*args, **kwargs)
#    2295 return result
#
# File /usr/local/lib/python3.9/site-packages/IPython/extensions/autoreload.py:599, in AutoreloadMagics.aimport(self, parameter_s, stream)
#     597 else:
#     598     for _module in [_.strip() for _ in modname.split(",")]:
# --> 599         top_module, top_name = self._reloader.aimport_module(_module)
#     601         # Inject module to user namespace
#     602         self.shell.push({top_name: top_module})
#
# File /usr/local/lib/python3.9/site-packages/IPython/extensions/autoreload.py:187, in ModuleReloader.aimport_module(self, module_name)
#     175 """Import a module, and mark it reloadable
#     176
#     177 Returns
#    (...)
#     183
#     184 """
#     185 self.mark_module_reloadable(module_name)
# --> 187 import_module(module_name)
#     188 top_name = module_name.split(".")[0]
#     189 top_module = sys.modules[top_name]
#
# File /usr/local/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Documents/GitHub/ubineer_nlp_research/content/peitong/../std_func.py:19, in <module>
#      17 from sklearn.cluster import KMeans
#      18 import plotly.express as px
# ---> 19 import pattern
#      20 import collections
#      21 from pattern.en import parsetree, singularize
#
# ModuleNotFoundError: No module named 'pattern'

# %% [markdown]
# ## Part-of-Speech (POS) Tagging - Cosine Similarity Analysis
# Part-of-speech (POS) tagging is a process of grammatical classification to classify texts into list of tuples where each word in the sentence gets a tag (label) that tells its part of speech (e.g. noun, pronoun, verb, adjective, adverb). According to Asoka Diggs, a Data Scientist at Intel, his research shows that nouns are better than n-grams. As a result, we used POS tagging to extract only nouns. We have examined the case with multiple-gram nouns. However, the results do not show distinct difference between documents, which may be caused by overfitting the model. Here we only consider 1-gram nouns. We conduct the consine similarity measure on the word counts from POS tagging.
#
# Source: https://databricks.com/session/nouns-are-better-than-n-grams

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string

# %% [markdown]
# ### Cosine Similarity Analysis

# %% [markdown]
# #### Word Counts from POS tagging
# We select the words with the word type `Noun` and use `CountVectorizer` from `sklearn.feature_extraction.text` to count the term frequency for each 1-gram noun and select the top 600 nouns by frequency

# %%
df = pd.read_csv('data/nouns_only.csv',
                 usecols = ['reportingDate', 'name', 'CIK', 'coDescription_lemmatized',
                           'coDescription_stopwords', 'coDescription_pos', 'SIC', 'SIC_desc'])
df = df.set_index(df.name)

# %%
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize

# %%
from sklearn.feature_extraction.text import CountVectorizer

Vectorizer = CountVectorizer(ngram_range = (1,1), 
                             max_features = 600)

count_data = Vectorizer.fit_transform(df['coDescription_pos'])
wordsCount_pos_tag = pd.DataFrame(count_data.toarray(),columns=Vectorizer.get_feature_names())
wordsCount_pos_tag = wordsCount_pos_tag.set_index(df['name'])
wordsCount_pos_tag
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                                   ability  acces  accordance  \
# name
# MONGODB, INC.                                           4      2           0
# SALESFORCE COM INC                                      0      3           0
# SPLUNK INC                                              2     13           0
# OKTA, INC.                                              0     26           0
# VEEVA SYSTEMS INC                                      46     12          21
# ...                                                   ...    ...         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.        2      1           2
# CYCLACEL PHARMACEUTICALS, INC.                          0      0           3
# ZOETIS INC.                                            11      3          16
# STAG INDUSTRIAL, INC.                                   1      5           2
# EQUINIX INC                                             4     15           0
#
#                                                   account  accounting  \
# name
# MONGODB, INC.                                           0           0
# SALESFORCE COM INC                                      1           0
# SPLUNK INC                                              2           0
# OKTA, INC.                                              2           0
# VEEVA SYSTEMS INC                                      34          68
# ...                                                   ...         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.        0           2
# CYCLACEL PHARMACEUTICALS, INC.                          0           0
# ZOETIS INC.                                            20          99
# STAG INDUSTRIAL, INC.                                   0           3
# EQUINIX INC                                             0           0
#
#                                                   acquisition  acre  acreage  \
# name
# MONGODB, INC.                                               2     0        0
# SALESFORCE COM INC                                          3     0        0
# SPLUNK INC                                                  2     0        0
# OKTA, INC.                                                  2     0        0
# VEEVA SYSTEMS INC                                          34     0        0
# ...                                                       ...   ...      ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.            3     0        0
# CYCLACEL PHARMACEUTICALS, INC.                              0     0        0
# ZOETIS INC.                                               123     0        0
# STAG INDUSTRIAL, INC.                                      12     0        0
# EQUINIX INC                                                 5     0        0
#
#                                                   act  action  ...  voting  \
# name                                                           ...
# MONGODB, INC.                                       2       0  ...       0
# SALESFORCE COM INC                                  0       2  ...       0
# SPLUNK INC                                          1       1  ...       0
# OKTA, INC.                                          0       0  ...       0
# VEEVA SYSTEMS INC                                  48      21  ...       9
# ...                                               ...     ...  ...     ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.    0       0  ...       0
# CYCLACEL PHARMACEUTICALS, INC.                      2       5  ...       0
# ZOETIS INC.                                        39      11  ...       0
# STAG INDUSTRIAL, INC.                               3       1  ...       0
# EQUINIX INC                                         2       0  ...       0
#
#                                                   waste  water  way  website  \
# name
# MONGODB, INC.                                         0      0    6        5
# SALESFORCE COM INC                                    0      0    3        3
# SPLUNK INC                                            0      0    2       12
# OKTA, INC.                                            0      0    6       10
# VEEVA SYSTEMS INC                                     0      0    4        5
# ...                                                 ...    ...  ...      ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.      0      1    0        4
# CYCLACEL PHARMACEUTICALS, INC.                        0      0    2        4
# ZOETIS INC.                                           7      0    3        0
# STAG INDUSTRIAL, INC.                                 2      0    0        5
# EQUINIX INC                                           0      0    2        3
#
#                                                   week  weight  work  year  \
# name
# MONGODB, INC.                                        0       0     6     9
# SALESFORCE COM INC                                   0       0     2     4
# SPLUNK INC                                           0       0     3     1
# OKTA, INC.                                           0       0     2     1
# VEEVA SYSTEMS INC                                    0       2     4   226
# ...                                                ...     ...   ...   ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.     0       0     0     5
# CYCLACEL PHARMACEUTICALS, INC.                       9       0     1     8
# ZOETIS INC.                                          0       1     2   159
# STAG INDUSTRIAL, INC.                                0       0     1     5
# EQUINIX INC                                          0       0     2    10
#
#                                                   york
# name
# MONGODB, INC.                                        2
# SALESFORCE COM INC                                   0
# SPLUNK INC                                           0
# OKTA, INC.                                           0
# VEEVA SYSTEMS INC                                    6
# ...                                                ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.    15
# CYCLACEL PHARMACEUTICALS, INC.                       0
# ZOETIS INC.                                          0
# STAG INDUSTRIAL, INC.                                1
# EQUINIX INC                                          2
#
# [675 rows x 600 columns]

# %% [markdown]
# #### Cosine Similarity Computation on on 1-Gram Nouns
# To determine the similarity of each company's business description, we use cosine similarity analysis on this POS-tagging with only nouns embeddings.

# %%
# Compute Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim_pos_tag = pd.DataFrame(cosine_similarity(wordsCount_pos_tag, wordsCount_pos_tag))
cosine_sim_pos_tag = cosine_sim_pos_tag.set_index(df['name'])
cosine_sim_pos_tag.columns = df['name']
cosine_sim_pos_tag
# Out:
# name                                              MONGODB, INC.  \
# name
# MONGODB, INC.                                          1.000000
# SALESFORCE COM INC                                     0.721505
# SPLUNK INC                                             0.712640
# OKTA, INC.                                             0.768272
# VEEVA SYSTEMS INC                                      0.469290
# ...                                                         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.       0.134490
# CYCLACEL PHARMACEUTICALS, INC.                         0.149307
# ZOETIS INC.                                            0.168299
# STAG INDUSTRIAL, INC.                                  0.156941
# EQUINIX INC                                            0.499246
#
# name                                              SALESFORCE COM INC  \
# name
# MONGODB, INC.                                               0.721505
# SALESFORCE COM INC                                          1.000000
# SPLUNK INC                                                  0.696715
# OKTA, INC.                                                  0.696564
# VEEVA SYSTEMS INC                                           0.626009
# ...                                                              ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.            0.179007
# CYCLACEL PHARMACEUTICALS, INC.                              0.143488
# ZOETIS INC.                                                 0.208971
# STAG INDUSTRIAL, INC.                                       0.131269
# EQUINIX INC                                                 0.680443
#
# name                                              SPLUNK INC  OKTA, INC.  \
# name
# MONGODB, INC.                                       0.712640    0.768272
# SALESFORCE COM INC                                  0.696715    0.696564
# SPLUNK INC                                          1.000000    0.713106
# OKTA, INC.                                          0.713106    1.000000
# VEEVA SYSTEMS INC                                   0.501298    0.471704
# ...                                                      ...         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.    0.140506    0.149249
# CYCLACEL PHARMACEUTICALS, INC.                      0.167965    0.168510
# ZOETIS INC.                                         0.158579    0.186875
# STAG INDUSTRIAL, INC.                               0.137773    0.149740
# EQUINIX INC                                         0.702077    0.540787
#
# name                                              VEEVA SYSTEMS INC  \
# name
# MONGODB, INC.                                              0.469290
# SALESFORCE COM INC                                         0.626009
# SPLUNK INC                                                 0.501298
# OKTA, INC.                                                 0.471704
# VEEVA SYSTEMS INC                                          1.000000
# ...                                                             ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.           0.386472
# CYCLACEL PHARMACEUTICALS, INC.                             0.181338
# ZOETIS INC.                                                0.630742
# STAG INDUSTRIAL, INC.                                      0.324082
# EQUINIX INC                                                0.488382
#
# name                                              AUTODESK INC  \
# name
# MONGODB, INC.                                         0.406578
# SALESFORCE COM INC                                    0.450280
# SPLUNK INC                                            0.445346
# OKTA, INC.                                            0.476666
# VEEVA SYSTEMS INC                                     0.358283
# ...                                                        ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.      0.121649
# CYCLACEL PHARMACEUTICALS, INC.                        0.196186
# ZOETIS INC.                                           0.224314
# STAG INDUSTRIAL, INC.                                 0.106612
# EQUINIX INC                                           0.302396
#
# name                                              INTERNATIONAL WESTERN PETROLEUM, INC.  \
# name
# MONGODB, INC.                                                                  0.127653
# SALESFORCE COM INC                                                             0.208104
# SPLUNK INC                                                                     0.161575
# OKTA, INC.                                                                     0.157277
# VEEVA SYSTEMS INC                                                              0.243000
# ...                                                                                 ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                               0.263172
# CYCLACEL PHARMACEUTICALS, INC.                                                 0.115146
# ZOETIS INC.                                                                    0.248238
# STAG INDUSTRIAL, INC.                                                          0.237217
# EQUINIX INC                                                                    0.180523
#
# name                                              DAYBREAK OIL & GAS, INC.  \
# name
# MONGODB, INC.                                                     0.141367
# SALESFORCE COM INC                                                0.205340
# SPLUNK INC                                                        0.146188
# OKTA, INC.                                                        0.158698
# VEEVA SYSTEMS INC                                                 0.287512
# ...                                                                    ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                  0.288564
# CYCLACEL PHARMACEUTICALS, INC.                                    0.125728
# ZOETIS INC.                                                       0.232798
# STAG INDUSTRIAL, INC.                                             0.310193
# EQUINIX INC                                                       0.143888
#
# name                                              ETERNAL SPEECH, INC.  \
# name
# MONGODB, INC.                                                 0.077973
# SALESFORCE COM INC                                            0.232427
# SPLUNK INC                                                    0.106176
# OKTA, INC.                                                    0.111659
# VEEVA SYSTEMS INC                                             0.310724
# ...                                                                ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0.367285
# CYCLACEL PHARMACEUTICALS, INC.                                0.067980
# ZOETIS INC.                                                   0.263805
# STAG INDUSTRIAL, INC.                                         0.122410
# EQUINIX INC                                                   0.160999
#
# name                                              ETERNAL SPEECH, INC.  ...  \
# name                                                                    ...
# MONGODB, INC.                                                 0.077973  ...
# SALESFORCE COM INC                                            0.232427  ...
# SPLUNK INC                                                    0.106176  ...
# OKTA, INC.                                                    0.111659  ...
# VEEVA SYSTEMS INC                                             0.310724  ...
# ...                                                                ...  ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0.367285  ...
# CYCLACEL PHARMACEUTICALS, INC.                                0.067980  ...
# ZOETIS INC.                                                   0.263805  ...
# STAG INDUSTRIAL, INC.                                         0.122410  ...
# EQUINIX INC                                                   0.160999  ...
#
# name                                              OMEGA HEALTHCARE INVESTORS INC  \
# name
# MONGODB, INC.                                                           0.123737
# SALESFORCE COM INC                                                      0.135028
# SPLUNK INC                                                              0.112114
# OKTA, INC.                                                              0.113043
# VEEVA SYSTEMS INC                                                       0.497539
# ...                                                                          ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                        0.415974
# CYCLACEL PHARMACEUTICALS, INC.                                          0.095797
# ZOETIS INC.                                                             0.502115
# STAG INDUSTRIAL, INC.                                                   0.312032
# EQUINIX INC                                                             0.120047
#
# name                                              TABLEAU SOFTWARE INC  \
# name
# MONGODB, INC.                                                 0.601398
# SALESFORCE COM INC                                            0.609349
# SPLUNK INC                                                    0.875391
# OKTA, INC.                                                    0.711460
# VEEVA SYSTEMS INC                                             0.472323
# ...                                                                ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0.136735
# CYCLACEL PHARMACEUTICALS, INC.                                0.222415
# ZOETIS INC.                                                   0.217181
# STAG INDUSTRIAL, INC.                                         0.139664
# EQUINIX INC                                                   0.622517
#
# name                                              HORIZON PHARMA PLC  \
# name
# MONGODB, INC.                                               0.143517
# SALESFORCE COM INC                                          0.158332
# SPLUNK INC                                                  0.140879
# OKTA, INC.                                                  0.158162
# VEEVA SYSTEMS INC                                           0.233799
# ...                                                              ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.            0.132879
# CYCLACEL PHARMACEUTICALS, INC.                              0.479660
# ZOETIS INC.                                                 0.192793
# STAG INDUSTRIAL, INC.                                       0.144205
# EQUINIX INC                                                 0.108056
#
# name                                              MERRIMACK PHARMACEUTICALS INC  \
# name
# MONGODB, INC.                                                          0.236362
# SALESFORCE COM INC                                                     0.213185
# SPLUNK INC                                                             0.235275
# OKTA, INC.                                                             0.338571
# VEEVA SYSTEMS INC                                                      0.262623
# ...                                                                         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                       0.116195
# CYCLACEL PHARMACEUTICALS, INC.                                         0.660791
# ZOETIS INC.                                                            0.233262
# STAG INDUSTRIAL, INC.                                                  0.123239
# EQUINIX INC                                                            0.154721
#
# name                                              REVEN HOUSING REIT, INC.  \
# name
# MONGODB, INC.                                                     0.174593
# SALESFORCE COM INC                                                0.176697
# SPLUNK INC                                                        0.159207
# OKTA, INC.                                                        0.171273
# VEEVA SYSTEMS INC                                                 0.335537
# ...                                                                    ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                  0.644117
# CYCLACEL PHARMACEUTICALS, INC.                                    0.106048
# ZOETIS INC.                                                       0.359660
# STAG INDUSTRIAL, INC.                                             0.686805
# EQUINIX INC                                                       0.172610
#
# name                                              AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.  \
# name
# MONGODB, INC.                                                                             0.134490
# SALESFORCE COM INC                                                                        0.179007
# SPLUNK INC                                                                                0.140506
# OKTA, INC.                                                                                0.149249
# VEEVA SYSTEMS INC                                                                         0.386472
# ...                                                                                            ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                                          1.000000
# CYCLACEL PHARMACEUTICALS, INC.                                                            0.097014
# ZOETIS INC.                                                                               0.402502
# STAG INDUSTRIAL, INC.                                                                     0.610487
# EQUINIX INC                                                                               0.124585
#
# name                                              CYCLACEL PHARMACEUTICALS, INC.  \
# name
# MONGODB, INC.                                                           0.149307
# SALESFORCE COM INC                                                      0.143488
# SPLUNK INC                                                              0.167965
# OKTA, INC.                                                              0.168510
# VEEVA SYSTEMS INC                                                       0.181338
# ...                                                                          ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                        0.097014
# CYCLACEL PHARMACEUTICALS, INC.                                          1.000000
# ZOETIS INC.                                                             0.139846
# STAG INDUSTRIAL, INC.                                                   0.097144
# EQUINIX INC                                                             0.128518
#
# name                                              ZOETIS INC.  \
# name
# MONGODB, INC.                                        0.168299
# SALESFORCE COM INC                                   0.208971
# SPLUNK INC                                           0.158579
# OKTA, INC.                                           0.186875
# VEEVA SYSTEMS INC                                    0.630742
# ...                                                       ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.     0.402502
# CYCLACEL PHARMACEUTICALS, INC.                       0.139846
# ZOETIS INC.                                          1.000000
# STAG INDUSTRIAL, INC.                                0.335454
# EQUINIX INC                                          0.165691
#
# name                                              STAG INDUSTRIAL, INC.  \
# name
# MONGODB, INC.                                                  0.156941
# SALESFORCE COM INC                                             0.131269
# SPLUNK INC                                                     0.137773
# OKTA, INC.                                                     0.149740
# VEEVA SYSTEMS INC                                              0.324082
# ...                                                                 ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.               0.610487
# CYCLACEL PHARMACEUTICALS, INC.                                 0.097144
# ZOETIS INC.                                                    0.335454
# STAG INDUSTRIAL, INC.                                          1.000000
# EQUINIX INC                                                    0.106782
#
# name                                              EQUINIX INC
# name
# MONGODB, INC.                                        0.499246
# SALESFORCE COM INC                                   0.680443
# SPLUNK INC                                           0.702077
# OKTA, INC.                                           0.540787
# VEEVA SYSTEMS INC                                    0.488382
# ...                                                       ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.     0.124585
# CYCLACEL PHARMACEUTICALS, INC.                       0.128518
# ZOETIS INC.                                          0.165691
# STAG INDUSTRIAL, INC.                                0.106782
# EQUINIX INC                                          1.000000
#
# [675 rows x 675 columns]

# %% [markdown]
# ### Performance Evaluation
# #### Predictions Based on the Closest Cosine Similarity Distance
# We use the closest neighborhood in terms of cosine similarity distances to evaluate the accuracy of the SIC classfication generated using POS-tagging with only 1-gram nouns embeddings and cosine similarity distances.

# %%
prediction, accuracy, cm = std_func.get_accuracy(cosine_sim_pos_tag, df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 prediction, accuracy, cm = std_func.get_accuracy(cosine_sim_pos_tag, df)
#
# NameError: name 'std_func' is not defined

# %%
cosine_sim_pos_tag_conf = std_func.conf_mat_cosine(cosine_sim_pos_tag, df)
cosine_sim_pos_tag_conf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 cosine_sim_pos_tag_conf = std_func.conf_mat_cosine(cosine_sim_pos_tag, df)
#       2 cosine_sim_pos_tag_conf
#
# NameError: name 'std_func' is not defined

# %% [markdown]
# From the above confusion matrix, cosine similarity analysis on POS-tagging with only 1-gram nouns embeddings gives an accuray of 94% on average. For industries `Crude Petroleum and Natural Gas`, `Real Estate Investment Trusts` and `State Commercial Banks (commercial banking)`, the accuracy is above 95%. `Prepackaged Software` gives the lowest accuracy at 86%. However, this confusion matrix gives extremely high prediction, we then look into the 2-D and 3-D plots to see if they are well-clustered.

# %% [markdown]
# ### Plotting
# #### Plotting on the Cosine Similarity Matrix
# We use PCA to automatically perform dimensionality reduction. First, we have a 2-D plot on cosine similarity matrix.

# %%
plot_cos_pos_tag = std_func.pca_visualize_2d(cosine_sim_pos_tag, df.loc[:,["name","SIC_desc"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 plot_cos_pos_tag = std_func.pca_visualize_2d(cosine_sim_pos_tag, df.loc[:,["name","SIC_desc"]])
#
# NameError: name 'std_func' is not defined

# %% [markdown]
# Here we have a 3-D plot with the first three dimensions which maximize the most variance.

# %%
std_func.pca_visualize_3d(plot_cos_pos_tag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 std_func.pca_visualize_3d(plot_cos_pos_tag)
#
# NameError: name 'std_func' is not defined

# %% [markdown]
# We can see from the above 3D plot that three industries are not well clustered. `Pharmaceutical Preparations` and `State Commercial Banks (commercial banking)` seem to be more spread out than others. The other three industries
# `Crude Petroleum and Natural Gas`, `Real Estate Investment Trusts` and `Prepackaged Software` are closely clustered with each other.

# %% [markdown]
# We can look at the explained variance of each dimension the PCA embedding of our cosine similatiry matrix generated from POS-tagging with only 1-gram nouns embeddings produced below:

# %%
plot_cos_pos_tag[0].explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 plot_cos_pos_tag[0].explained_variance_ratio_
#
# NameError: name 'plot_cos_pos_tag' is not defined

# %% [markdown]
# The total explained variance of the first three dimensions are:

# %%
plot_cos_pos_tag[0].explained_variance_ratio_[0:3].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 plot_cos_pos_tag[0].explained_variance_ratio_[0:3].sum()
#
# NameError: name 'plot_cos_pos_tag' is not defined

# %% [markdown]
# The first three dimensions explained 78% of the total variance that exists within the data.

# %% [markdown]
# ### Conclusion Reporting

# %%
from sklearn.metrics import classification_report
print(classification_report(prediction["y_true"], prediction["y_pred"], target_names=df["SIC_desc"].unique()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(prediction["y_true"], prediction["y_pred"], target_names=df["SIC_desc"].unique()))
#
# NameError: name 'prediction' is not defined

# %% [markdown]
# We can see from the above classification_report, we can conclude that cosine similarity analysis on POS-tagging with 1-gram nouns embeddings gives a good result on SIC classfication, specifically on the industries `Crude Petroleum and Natural Gas`, `Real Estate Investment Trusts` and `State Commercial Banks (commercial banking)`.

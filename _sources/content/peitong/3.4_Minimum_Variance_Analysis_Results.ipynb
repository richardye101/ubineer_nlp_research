# %%
import pandas as pd

# %% [markdown]
# ### Pharmaceutical Preparations

# %%
sample_pharm = pd.read_csv("data/min_vol_sample_Pharmaceutical_Preparations.csv")
cos_sim_pharm = pd.read_csv("data/min_vol_cos_sim_Pharmaceutical_Preparations.csv")
factor_model_pharm = pd.read_csv("data/min_vol_factor_model_Pharmaceutical_Preparations.csv")

# %%
sample_pharm = sample_pharm.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
cos_sim_pharm = cos_sim_pharm.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
factor_model_pharm = factor_model_pharm.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)

# %%
columns = pd.MultiIndex.from_product([['Sample Estimate', 'Cosine Similarity Estimate', 'Factor Model Estimate'], 
                                      ['Company Name', 'Weight']])
pharm = pd.concat([pd.concat([sample_pharm, cos_sim_pharm], axis=1), factor_model_pharm], axis=1)
pharm.columns = columns
Same = (set(sample_pharm.Company_Name) & set(cos_sim_pharm.Company_Name)) & set(factor_model_pharm.Company_Name)

# %%
def highlight(val):
    color = 'blue' if val in Same else 'black'
    return 'color: %s' % color

# %%
pharm.style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_edabe_row0_col0, #T_edabe_row0_col1, #T_edabe_row0_col2, #T_edabe_row0_col3, #T_edabe_row0_col5, #T_edabe_row1_col1, #T_edabe_row1_col3, #T_edabe_row1_col4, #T_edabe_row1_col5, #T_edabe_row2_col0, #T_edabe_row2_col1, #T_edabe_row2_col3, #T_edabe_row2_col5, #T_edabe_row3_col0, #T_edabe_row3_col1, #T_edabe_row3_col2, #T_edabe_row3_col3, #T_edabe_row3_col4, #T_edabe_row3_col5, #T_edabe_row4_col0, #T_edabe_row4_col1, #T_edabe_row4_col2, #T_edabe_row4_col3, #T_edabe_row4_col4, #T_edabe_row4_col5, #T_edabe_row5_col0, #T_edabe_row5_col1, #T_edabe_row5_col2, #T_edabe_row5_col3, #T_edabe_row5_col4, #T_edabe_row5_col5, #T_edabe_row6_col0, #T_edabe_row6_col1, #T_edabe_row6_col2, #T_edabe_row6_col3, #T_edabe_row6_col4, #T_edabe_row6_col5, #T_edabe_row7_col0, #T_edabe_row7_col1, #T_edabe_row7_col2, #T_edabe_row7_col3, #T_edabe_row7_col4, #T_edabe_row7_col5, #T_edabe_row8_col0, #T_edabe_row8_col1, #T_edabe_row8_col2, #T_edabe_row8_col3, #T_edabe_row8_col4, #T_edabe_row8_col5, #T_edabe_row9_col0, #T_edabe_row9_col1, #T_edabe_row9_col2, #T_edabe_row9_col3, #T_edabe_row9_col4, #T_edabe_row9_col5, #T_edabe_row10_col0, #T_edabe_row10_col1, #T_edabe_row10_col2, #T_edabe_row10_col3, #T_edabe_row10_col4, #T_edabe_row10_col5, #T_edabe_row11_col0, #T_edabe_row11_col1, #T_edabe_row11_col2, #T_edabe_row11_col3, #T_edabe_row11_col4, #T_edabe_row11_col5, #T_edabe_row12_col0, #T_edabe_row12_col1, #T_edabe_row12_col2, #T_edabe_row12_col3, #T_edabe_row12_col4, #T_edabe_row12_col5, #T_edabe_row13_col0, #T_edabe_row13_col1, #T_edabe_row13_col2, #T_edabe_row13_col3, #T_edabe_row13_col4, #T_edabe_row13_col5, #T_edabe_row14_col0, #T_edabe_row14_col1, #T_edabe_row14_col2, #T_edabe_row14_col3, #T_edabe_row14_col4, #T_edabe_row14_col5, #T_edabe_row15_col0, #T_edabe_row15_col1, #T_edabe_row15_col2, #T_edabe_row15_col3, #T_edabe_row15_col4, #T_edabe_row15_col5, #T_edabe_row16_col1, #T_edabe_row16_col2, #T_edabe_row16_col3, #T_edabe_row16_col4, #T_edabe_row16_col5, #T_edabe_row17_col0, #T_edabe_row17_col1, #T_edabe_row17_col2, #T_edabe_row17_col3, #T_edabe_row17_col4, #T_edabe_row17_col5, #T_edabe_row18_col0, #T_edabe_row18_col1, #T_edabe_row18_col2, #T_edabe_row18_col3, #T_edabe_row18_col4, #T_edabe_row18_col5, #T_edabe_row19_col0, #T_edabe_row19_col1, #T_edabe_row19_col2, #T_edabe_row19_col3, #T_edabe_row19_col4, #T_edabe_row19_col5, #T_edabe_row20_col0, #T_edabe_row20_col1, #T_edabe_row20_col2, #T_edabe_row20_col3, #T_edabe_row20_col4, #T_edabe_row20_col5 {
#   color: black;
# }
# #T_edabe_row0_col4, #T_edabe_row1_col0, #T_edabe_row1_col2, #T_edabe_row2_col2, #T_edabe_row2_col4, #T_edabe_row16_col0 {
#   color: blue;
# }
# </style>
# <table id="T_edabe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edabe_level0_col0" class="col_heading level0 col0" colspan="2">Sample Estimate</th>
#       <th id="T_edabe_level0_col2" class="col_heading level0 col2" colspan="2">Cosine Similarity Estimate</th>
#       <th id="T_edabe_level0_col4" class="col_heading level0 col4" colspan="2">Factor Model Estimate</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_edabe_level1_col0" class="col_heading level1 col0" >Company Name</th>
#       <th id="T_edabe_level1_col1" class="col_heading level1 col1" >Weight</th>
#       <th id="T_edabe_level1_col2" class="col_heading level1 col2" >Company Name</th>
#       <th id="T_edabe_level1_col3" class="col_heading level1 col3" >Weight</th>
#       <th id="T_edabe_level1_col4" class="col_heading level1 col4" >Company Name</th>
#       <th id="T_edabe_level1_col5" class="col_heading level1 col5" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edabe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edabe_row0_col0" class="data row0 col0" >MERCK & CO., INC.</td>
#       <td id="T_edabe_row0_col1" class="data row0 col1" >0.200000</td>
#       <td id="T_edabe_row0_col2" class="data row0 col2" >PFIZER INC</td>
#       <td id="T_edabe_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_edabe_row0_col4" class="data row0 col4" >ZOETIS INC.</td>
#       <td id="T_edabe_row0_col5" class="data row0 col5" >0.158670</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edabe_row1_col0" class="data row1 col0" >JOHNSON & JOHNSON</td>
#       <td id="T_edabe_row1_col1" class="data row1 col1" >0.178780</td>
#       <td id="T_edabe_row1_col2" class="data row1 col2" >ZOETIS INC.</td>
#       <td id="T_edabe_row1_col3" class="data row1 col3" >0.200000</td>
#       <td id="T_edabe_row1_col4" class="data row1 col4" >NATURES SUNSHINE PRODUCTS INC</td>
#       <td id="T_edabe_row1_col5" class="data row1 col5" >0.125070</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edabe_row2_col0" class="data row2 col0" >BRISTOL MYERS SQUIBB CO</td>
#       <td id="T_edabe_row2_col1" class="data row2 col1" >0.128240</td>
#       <td id="T_edabe_row2_col2" class="data row2 col2" >JOHNSON & JOHNSON</td>
#       <td id="T_edabe_row2_col3" class="data row2 col3" >0.187560</td>
#       <td id="T_edabe_row2_col4" class="data row2 col4" >JOHNSON & JOHNSON</td>
#       <td id="T_edabe_row2_col5" class="data row2 col5" >0.106000</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edabe_row3_col0" class="data row3 col0" >ASSEMBLY BIOSCIENCES, INC.</td>
#       <td id="T_edabe_row3_col1" class="data row3 col1" >0.057750</td>
#       <td id="T_edabe_row3_col2" class="data row3 col2" >MERCK & CO., INC.</td>
#       <td id="T_edabe_row3_col3" class="data row3 col3" >0.137530</td>
#       <td id="T_edabe_row3_col4" class="data row3 col4" >TELIGENT, INC.</td>
#       <td id="T_edabe_row3_col5" class="data row3 col5" >0.087730</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edabe_row4_col0" class="data row4 col0" >PROPHASE LABS, INC.</td>
#       <td id="T_edabe_row4_col1" class="data row4 col1" >0.051200</td>
#       <td id="T_edabe_row4_col2" class="data row4 col2" >BIOSPECIFICS TECHNOLOGIES CORP</td>
#       <td id="T_edabe_row4_col3" class="data row4 col3" >0.073940</td>
#       <td id="T_edabe_row4_col4" class="data row4 col4" >ARENA PHARMACEUTICALS INC</td>
#       <td id="T_edabe_row4_col5" class="data row4 col5" >0.076820</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_edabe_row5_col0" class="data row5 col0" >ORAMED PHARMACEUTICALS INC.</td>
#       <td id="T_edabe_row5_col1" class="data row5 col1" >0.049820</td>
#       <td id="T_edabe_row5_col2" class="data row5 col2" >BIOMARIN PHARMACEUTICAL INC</td>
#       <td id="T_edabe_row5_col3" class="data row5 col3" >0.045720</td>
#       <td id="T_edabe_row5_col4" class="data row5 col4" >PROGENICS PHARMACEUTICALS INC</td>
#       <td id="T_edabe_row5_col5" class="data row5 col5" >0.070630</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edabe_row6_col0" class="data row6 col0" >STEMLINE THERAPEUTICS INC</td>
#       <td id="T_edabe_row6_col1" class="data row6 col1" >0.042730</td>
#       <td id="T_edabe_row6_col2" class="data row6 col2" >BRISTOL MYERS SQUIBB CO</td>
#       <td id="T_edabe_row6_col3" class="data row6 col3" >0.037190</td>
#       <td id="T_edabe_row6_col4" class="data row6 col4" >FLEXION THERAPEUTICS INC</td>
#       <td id="T_edabe_row6_col5" class="data row6 col5" >0.064940</td>
#     </tr>
#     <tr>
#       <th id="T_edabe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edabe_row7_col0" class="data row7 col0" >IMPRIMIS PHARMACEUTICALS, INC.</td>
#       <td id="T_edabe_row7_col1" class="data row7 col1" >0.041810</td>
#       <td id="T_edabe_row7_col2" class="data row7 col2" >LILLY ELI & CO</td>
#       <td id="T_edabe_row7_col3" class="data row7 col3" >0.035620</td>
#       <td id="T_edabe_row7_col4" class="data

# %% [markdown]
# ### Prepackaged Software (mass reproduction of software)

# %%
sample_software = pd.read_csv("data/min_vol_sample_Prepackaged_Software.csv")
cos_sim_software = pd.read_csv("data/min_vol_cos_sim_Prepackaged_Software.csv")
factor_model_software = pd.read_csv("data/min_vol_factor_model_Prepackaged_Software.csv")

# %%
sample_software = sample_software.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
cos_sim_software = cos_sim_software.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
factor_model_software = factor_model_software.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)

# %%
columns = pd.MultiIndex.from_product([['Sample Estimate', 'Cosine Similarity Estimate', 'Factor Model Estimate'], 
                                      ['Company Name', 'Weight']])
software = pd.concat([pd.concat([sample_software, cos_sim_software], axis=1), factor_model_software], axis=1)
software.columns = columns
Same = (set(sample_software.Company_Name) & set(cos_sim_software.Company_Name)) & set(factor_model_software.Company_Name)

# %%
software.style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_0109a_row0_col0, #T_0109a_row0_col1, #T_0109a_row0_col3, #T_0109a_row0_col4, #T_0109a_row0_col5, #T_0109a_row1_col1, #T_0109a_row1_col2, #T_0109a_row1_col3, #T_0109a_row1_col4, #T_0109a_row1_col5, #T_0109a_row2_col0, #T_0109a_row2_col1, #T_0109a_row2_col2, #T_0109a_row2_col3, #T_0109a_row2_col4, #T_0109a_row2_col5, #T_0109a_row3_col0, #T_0109a_row3_col1, #T_0109a_row3_col2, #T_0109a_row3_col3, #T_0109a_row3_col4, #T_0109a_row3_col5, #T_0109a_row4_col0, #T_0109a_row4_col1, #T_0109a_row4_col2, #T_0109a_row4_col3, #T_0109a_row4_col4, #T_0109a_row4_col5, #T_0109a_row5_col0, #T_0109a_row5_col1, #T_0109a_row5_col2, #T_0109a_row5_col3, #T_0109a_row5_col4, #T_0109a_row5_col5, #T_0109a_row6_col0, #T_0109a_row6_col1, #T_0109a_row6_col2, #T_0109a_row6_col3, #T_0109a_row6_col4, #T_0109a_row6_col5, #T_0109a_row7_col0, #T_0109a_row7_col1, #T_0109a_row7_col2, #T_0109a_row7_col3, #T_0109a_row7_col4, #T_0109a_row7_col5, #T_0109a_row8_col0, #T_0109a_row8_col1, #T_0109a_row8_col2, #T_0109a_row8_col3, #T_0109a_row8_col4, #T_0109a_row8_col5, #T_0109a_row9_col0, #T_0109a_row9_col1, #T_0109a_row9_col2, #T_0109a_row9_col3, #T_0109a_row9_col4, #T_0109a_row9_col5, #T_0109a_row10_col0, #T_0109a_row10_col1, #T_0109a_row10_col2, #T_0109a_row10_col3, #T_0109a_row10_col4, #T_0109a_row10_col5, #T_0109a_row11_col0, #T_0109a_row11_col1, #T_0109a_row11_col2, #T_0109a_row11_col3, #T_0109a_row11_col4, #T_0109a_row11_col5, #T_0109a_row12_col0, #T_0109a_row12_col1, #T_0109a_row12_col2, #T_0109a_row12_col3, #T_0109a_row12_col4, #T_0109a_row12_col5, #T_0109a_row13_col0, #T_0109a_row13_col1, #T_0109a_row13_col2, #T_0109a_row13_col3, #T_0109a_row13_col4, #T_0109a_row13_col5, #T_0109a_row14_col0, #T_0109a_row14_col1, #T_0109a_row14_col2, #T_0109a_row14_col3, #T_0109a_row14_col4, #T_0109a_row14_col5, #T_0109a_row15_col0, #T_0109a_row15_col1, #T_0109a_row15_col2, #T_0109a_row15_col3, #T_0109a_row15_col5, #T_0109a_row16_col0, #T_0109a_row16_col1, #T_0109a_row16_col2, #T_0109a_row16_col3, #T_0109a_row16_col4, #T_0109a_row16_col5, #T_0109a_row17_col0, #T_0109a_row17_col1, #T_0109a_row17_col2, #T_0109a_row17_col3, #T_0109a_row17_col4, #T_0109a_row17_col5 {
#   color: black;
# }
# #T_0109a_row0_col2, #T_0109a_row1_col0, #T_0109a_row15_col4 {
#   color: blue;
# }
# </style>
# <table id="T_0109a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0109a_level0_col0" class="col_heading level0 col0" colspan="2">Sample Estimate</th>
#       <th id="T_0109a_level0_col2" class="col_heading level0 col2" colspan="2">Cosine Similarity Estimate</th>
#       <th id="T_0109a_level0_col4" class="col_heading level0 col4" colspan="2">Factor Model Estimate</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_0109a_level1_col0" class="col_heading level1 col0" >Company Name</th>
#       <th id="T_0109a_level1_col1" class="col_heading level1 col1" >Weight</th>
#       <th id="T_0109a_level1_col2" class="col_heading level1 col2" >Company Name</th>
#       <th id="T_0109a_level1_col3" class="col_heading level1 col3" >Weight</th>
#       <th id="T_0109a_level1_col4" class="col_heading level1 col4" >Company Name</th>
#       <th id="T_0109a_level1_col5" class="col_heading level1 col5" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0109a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0109a_row0_col0" class="data row0 col0" >AWARE INC /MA/</td>
#       <td id="T_0109a_row0_col1" class="data row0 col1" >0.200000</td>
#       <td id="T_0109a_row0_col2" class="data row0 col2" >BLACK KNIGHT, INC.</td>
#       <td id="T_0109a_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_0109a_row0_col4" class="data row0 col4" >POLARITYTE, INC.</td>
#       <td id="T_0109a_row0_col5" class="data row0 col5" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0109a_row1_col0" class="data row1 col0" >BLACK KNIGHT, INC.</td>
#       <td id="T_0109a_row1_col1" class="data row1 col1" >0.200000</td>
#       <td id="T_0109a_row1_col2" class="data row1 col2" >ORACLE CORP</td>
#       <td id="T_0109a_row1_col3" class="data row1 col3" >0.163150</td>
#       <td id="T_0109a_row1_col4" class="data row1 col4" >2U, INC.</td>
#       <td id="T_0109a_row1_col5" class="data row1 col5" >0.172820</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0109a_row2_col0" class="data row2 col0" >ACI WORLDWIDE, INC.</td>
#       <td id="T_0109a_row2_col1" class="data row2 col1" >0.113140</td>
#       <td id="T_0109a_row2_col2" class="data row2 col2" >ANSYS INC</td>
#       <td id="T_0109a_row2_col3" class="data row2 col3" >0.153900</td>
#       <td id="T_0109a_row2_col4" class="data row2 col4" >MICROSTRATEGY INC</td>
#       <td id="T_0109a_row2_col5" class="data row2 col5" >0.127520</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0109a_row3_col0" class="data row3 col0" >ORACLE CORP</td>
#       <td id="T_0109a_row3_col1" class="data row3 col1" >0.091700</td>
#       <td id="T_0109a_row3_col2" class="data row3 col2" >ULTIMATE SOFTWARE GROUP INC</td>
#       <td id="T_0109a_row3_col3" class="data row3 col3" >0.103500</td>
#       <td id="T_0109a_row3_col4" class="data row3 col4" >ENDURANCE INTERNATIONAL GROUP HOLDINGS, INC.</td>
#       <td id="T_0109a_row3_col5" class="data row3 col5" >0.112280</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0109a_row4_col0" class="data row4 col0" >NUANCE COMMUNICATIONS, INC.</td>
#       <td id="T_0109a_row4_col1" class="data row4 col1" >0.086080</td>
#       <td id="T_0109a_row4_col2" class="data row4 col2" >NATIONAL INSTRUMENTS CORP</td>
#       <td id="T_0109a_row4_col3" class="data row4 col3" >0.093720</td>
#       <td id="T_0109a_row4_col4" class="data row4 col4" >ANSYS INC</td>
#       <td id="T_0109a_row4_col5" class="data row4 col5" >0.067520</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0109a_row5_col0" class="data row5 col0" >COMMVAULT SYSTEMS INC</td>
#       <td id="T_0109a_row5_col1" class="data row5 col1" >0.073810</td>
#       <td id="T_0109a_row5_col2" class="data row5 col2" >Q2 HOLDINGS, INC.</td>
#       <td id="T_0109a_row5_col3" class="data row5 col3" >0.061900</td>
#       <td id="T_0109a_row5_col4" class="data row5 col4" >TABLEAU SOFTWARE INC</td>
#       <td id="T_0109a_row5_col5" class="data row5 col5" >0.056140</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0109a_row6_col0" class="data row6 col0" >QUALYS, INC.</td>
#       <td id="T_0109a_row6_col1" class="data row6 col1" >0.066680</td>
#       <td id="T_0109a_row6_col2" class="data row6 col2" >NUANCE COMMUNICATIONS, INC.</td>
#       <td id="T_0109a_row6_col3" class="data row6 col3" >0.059470</td>
#       <td id="T_0109a_row6_col4" class="data row6 col4" >QUMU CORP</td>
#       <td id="T_0109a_row6_col5" class="data row6 col5" >0.047250</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0109a_row7_col0" class="data row7 col0" >QUMU CORP</td>
#       <td id="T_0109a_row7_col1" class="data row7 col1" >0.051530</td>
#       <td id="T_0109a_row7_col2" class="data row7 col2" >ACI WORLDWIDE, INC.</td>
#       <td id="T_0109a_row7_col3" class="data row7 col3" >0.047540</td>
#       <td id="T_0109a_row7_col4" class="data row7 col4" >BRIDGELINE DIGITAL, INC.</td>
#       <td id="T_0109a_row7_col5" class="data row7 col5" >0.035930</td>
#     </tr>
#     <tr>
#       <th id="T_0109a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0109a_row8_col0" class="data row8 col0" >ENDURANCE INTERNATIONAL GROUP HOLDINGS, INC.</td>
#       <td id="T_0109a_row8_col1" class="data row8 col1" >0.025540</td>
#       <td id="T_0109a_row8_col2" class="data row8 col2" >GSE SYSTEMS

# %% [markdown]
# ### Real Estate Investment Trusts

# %%
sample_real_estate = pd.read_csv("data/min_vol_sample_Real_Estate_Investment_Trusts.csv")
cos_sim_real_estate = pd.read_csv("data/min_vol_cos_sim_Real_Estate_Investment_Trusts.csv")
factor_model_real_estate = pd.read_csv("data/min_vol_factor_model_Real_Estate_Investment_Trusts.csv")

# %%
sample_real_estate = sample_real_estate.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
cos_sim_real_estate = cos_sim_real_estate.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
factor_model_real_estate = factor_model_real_estate.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)

# %%
columns = pd.MultiIndex.from_product([['Sample Estimate', 'Cosine Similarity Estimate', 'Factor Model Estimate'], 
                                      ['Company Name', 'Weight']])
real_estate = pd.concat([pd.concat([sample_real_estate, cos_sim_real_estate], axis=1), factor_model_real_estate], axis=1)
real_estate.columns = columns
Same = (set(sample_real_estate.Company_Name) & set(cos_sim_real_estate.Company_Name)) & set(factor_model_real_estate.Company_Name)

# %%
real_estate.style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_f8dd0_row0_col0, #T_f8dd0_row0_col1, #T_f8dd0_row0_col3, #T_f8dd0_row0_col4, #T_f8dd0_row0_col5, #T_f8dd0_row1_col1, #T_f8dd0_row1_col2, #T_f8dd0_row1_col3, #T_f8dd0_row1_col4, #T_f8dd0_row1_col5, #T_f8dd0_row2_col1, #T_f8dd0_row2_col2, #T_f8dd0_row2_col3, #T_f8dd0_row2_col4, #T_f8dd0_row2_col5, #T_f8dd0_row3_col0, #T_f8dd0_row3_col1, #T_f8dd0_row3_col2, #T_f8dd0_row3_col3, #T_f8dd0_row3_col4, #T_f8dd0_row3_col5, #T_f8dd0_row4_col0, #T_f8dd0_row4_col1, #T_f8dd0_row4_col2, #T_f8dd0_row4_col3, #T_f8dd0_row4_col4, #T_f8dd0_row4_col5, #T_f8dd0_row5_col0, #T_f8dd0_row5_col1, #T_f8dd0_row5_col2, #T_f8dd0_row5_col3, #T_f8dd0_row5_col4, #T_f8dd0_row5_col5, #T_f8dd0_row6_col0, #T_f8dd0_row6_col1, #T_f8dd0_row6_col2, #T_f8dd0_row6_col3, #T_f8dd0_row6_col4, #T_f8dd0_row6_col5, #T_f8dd0_row7_col0, #T_f8dd0_row7_col1, #T_f8dd0_row7_col2, #T_f8dd0_row7_col3, #T_f8dd0_row7_col4, #T_f8dd0_row7_col5, #T_f8dd0_row8_col0, #T_f8dd0_row8_col1, #T_f8dd0_row8_col2, #T_f8dd0_row8_col3, #T_f8dd0_row8_col4, #T_f8dd0_row8_col5, #T_f8dd0_row9_col0, #T_f8dd0_row9_col1, #T_f8dd0_row9_col2, #T_f8dd0_row9_col3, #T_f8dd0_row9_col5, #T_f8dd0_row10_col0, #T_f8dd0_row10_col1, #T_f8dd0_row10_col3, #T_f8dd0_row10_col4, #T_f8dd0_row10_col5, #T_f8dd0_row11_col0, #T_f8dd0_row11_col1, #T_f8dd0_row11_col2, #T_f8dd0_row11_col3, #T_f8dd0_row11_col4, #T_f8dd0_row11_col5, #T_f8dd0_row12_col0, #T_f8dd0_row12_col1, #T_f8dd0_row12_col2, #T_f8dd0_row12_col3, #T_f8dd0_row12_col4, #T_f8dd0_row12_col5, #T_f8dd0_row13_col0, #T_f8dd0_row13_col1, #T_f8dd0_row13_col2, #T_f8dd0_row13_col3, #T_f8dd0_row13_col4, #T_f8dd0_row13_col5, #T_f8dd0_row14_col0, #T_f8dd0_row14_col1, #T_f8dd0_row14_col2, #T_f8dd0_row14_col3, #T_f8dd0_row14_col4, #T_f8dd0_row14_col5, #T_f8dd0_row15_col0, #T_f8dd0_row15_col1, #T_f8dd0_row15_col2, #T_f8dd0_row15_col3, #T_f8dd0_row15_col4, #T_f8dd0_row15_col5, #T_f8dd0_row16_col0, #T_f8dd0_row16_col1, #T_f8dd0_row16_col2, #T_f8dd0_row16_col3, #T_f8dd0_row16_col4, #T_f8dd0_row16_col5, #T_f8dd0_row17_col0, #T_f8dd0_row17_col1, #T_f8dd0_row17_col2, #T_f8dd0_row17_col3, #T_f8dd0_row17_col4, #T_f8dd0_row17_col5, #T_f8dd0_row18_col0, #T_f8dd0_row18_col1, #T_f8dd0_row18_col2, #T_f8dd0_row18_col3, #T_f8dd0_row18_col4, #T_f8dd0_row18_col5, #T_f8dd0_row19_col0, #T_f8dd0_row19_col1, #T_f8dd0_row19_col2, #T_f8dd0_row19_col3, #T_f8dd0_row19_col4, #T_f8dd0_row19_col5, #T_f8dd0_row20_col0, #T_f8dd0_row20_col1, #T_f8dd0_row20_col2, #T_f8dd0_row20_col3, #T_f8dd0_row20_col4, #T_f8dd0_row20_col5, #T_f8dd0_row21_col0, #T_f8dd0_row21_col1, #T_f8dd0_row21_col2, #T_f8dd0_row21_col3, #T_f8dd0_row21_col4, #T_f8dd0_row21_col5, #T_f8dd0_row22_col0, #T_f8dd0_row22_col1, #T_f8dd0_row22_col2, #T_f8dd0_row22_col3, #T_f8dd0_row22_col4, #T_f8dd0_row22_col5, #T_f8dd0_row23_col0, #T_f8dd0_row23_col1, #T_f8dd0_row23_col2, #T_f8dd0_row23_col3, #T_f8dd0_row23_col4, #T_f8dd0_row23_col5, #T_f8dd0_row24_col0, #T_f8dd0_row24_col1, #T_f8dd0_row24_col2, #T_f8dd0_row24_col3, #T_f8dd0_row24_col5, #T_f8dd0_row25_col0, #T_f8dd0_row25_col1, #T_f8dd0_row25_col2, #T_f8dd0_row25_col3, #T_f8dd0_row25_col4, #T_f8dd0_row25_col5 {
#   color: black;
# }
# #T_f8dd0_row0_col2, #T_f8dd0_row1_col0, #T_f8dd0_row2_col0, #T_f8dd0_row9_col4, #T_f8dd0_row10_col2, #T_f8dd0_row24_col4 {
#   color: blue;
# }
# </style>
# <table id="T_f8dd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8dd0_level0_col0" class="col_heading level0 col0" colspan="2">Sample Estimate</th>
#       <th id="T_f8dd0_level0_col2" class="col_heading level0 col2" colspan="2">Cosine Similarity Estimate</th>
#       <th id="T_f8dd0_level0_col4" class="col_heading level0 col4" colspan="2">Factor Model Estimate</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_f8dd0_level1_col0" class="col_heading level1 col0" >Company Name</th>
#       <th id="T_f8dd0_level1_col1" class="col_heading level1 col1" >Weight</th>
#       <th id="T_f8dd0_level1_col2" class="col_heading level1 col2" >Company Name</th>
#       <th id="T_f8dd0_level1_col3" class="col_heading level1 col3" >Weight</th>
#       <th id="T_f8dd0_level1_col4" class="col_heading level1 col4" >Company Name</th>
#       <th id="T_f8dd0_level1_col5" class="col_heading level1 col5" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8dd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8dd0_row0_col0" class="data row0 col0" >GREAT AJAX CORP.</td>
#       <td id="T_f8dd0_row0_col1" class="data row0 col1" >0.200000</td>
#       <td id="T_f8dd0_row0_col2" class="data row0 col2" >EQUITY COMMONWEALTH</td>
#       <td id="T_f8dd0_row0_col3" class="data row0 col3" >0.163270</td>
#       <td id="T_f8dd0_row0_col4" class="data row0 col4" >EQUITY RESIDENTIAL</td>
#       <td id="T_f8dd0_row0_col5" class="data row0 col5" >0.126770</td>
#     </tr>
#     <tr>
#       <th id="T_f8dd0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8dd0_row1_col0" class="data row1 col0" >EQUITY COMMONWEALTH</td>
#       <td id="T_f8dd0_row1_col1" class="data row1 col1" >0.200000</td>
#       <td id="T_f8dd0_row1_col2" class="data row1 col2" >SUN COMMUNITIES INC</td>
#       <td id="T_f8dd0_row1_col3" class="data row1 col3" >0.149070</td>
#       <td id="T_f8dd0_row1_col4" class="data row1 col4" >CYRUSONE INC.</td>
#       <td id="T_f8dd0_row1_col5" class="data row1 col5" >0.085230</td>
#     </tr>
#     <tr>
#       <th id="T_f8dd0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8dd0_row2_col0" class="data row2 col0" >HMG COURTLAND PROPERTIES INC</td>
#       <td id="T_f8dd0_row2_col1" class="data row2 col1" >0.125130</td>
#       <td id="T_f8dd0_row2_col2" class="data row2 col2" >GREAT AJAX CORP.</td>
#       <td id="T_f8dd0_row2_col3" class="data row2 col3" >0.138060</td>
#       <td id="T_f8dd0_row2_col4" class="data row2 col4" >HOWARD HUGHES CORP</td>
#       <td id="T_f8dd0_row2_col5" class="data row2 col5" >0.080410</td>
#     </tr>
#     <tr>
#       <th id="T_f8dd0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8dd0_row3_col0" class="data row3 col0" >PUBLIC STORAGE</td>
#       <td id="T_f8dd0_row3_col1" class="data row3 col1" >0.109380</td>
#       <td id="T_f8dd0_row3_col2" class="data row3 col2" >EQUINIX INC</td>
#       <td id="T_f8dd0_row3_col3" class="data row3 col3" >0.070680</td>
#       <td id="T_f8dd0_row3_col4" class="data row3 col4" >KILROY REALTY CORP</td>
#       <td id="T_f8dd0_row3_col5" class="data row3 col5" >0.078640</td>
#     </tr>
#     <tr>
#       <th id="T_f8dd0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8dd0_row4_col0" class="data row4 col0" >ARES COMMERCIAL REAL ESTATE CORP</td>
#       <td id="T_f8dd0_row4_col1" class="data row4 col1" >0.091070</td>
#       <td id="T_f8dd0_row4_col2" class="data row4 col2" >GAMING & LEISURE PROPERTIES, INC.</td>
#       <td id="T_f8dd0_row4_col3" class="data row4 col3" >0.067340</td>
#       <td id="T_f8dd0_row4_col4" class="data row4 col4" >LAMAR ADVERTISING CO/NEW</td>
#       <td id="T_f8dd0_row4_col5" class="data row4 col5" >0.074460</td>
#     </tr>
#     <tr>
#       <th id="T_f8dd0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8dd0_row5_col0" class="data row5 col0" >CIM COMMERCIAL TRUST CORP</td>
#       <td id="T_f8dd0_row5_col1" class="data row5 col1" >0.054610</td>
#       <td id="T_f8dd0_row5_col2" class="data row5 col2" >PUBLIC STORAGE</td>
#       <td id="T_f8dd0_row5_col3" class="data row5 col3" >0.063390</td>
#       <td id="T_f8dd0_row5_col4" class="data row5 col4" >OUTFRONT MEDIA INC.</td>
#       <td id="T_f8dd0_row5_col5" class="data row5 col5" >0.073000</td>
#     </tr>
#     <tr>
#       <th id="T_f8dd0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f8dd0_row6_col0" class="data row6 col0" >IMPAC MORTGAGE HOLDINGS INC</td>
#       <td id="T_f8dd0_row6_col1" class="data row6 col1" >0.051080</td>
#       <td id="T_f8dd0_row6_col2" class="data row6 col2" >DUKE REALTY CORP</td>
#       <td id="T_f8dd0_row6_col3" class="data row6 col3" >0.053690

# %% [markdown]
# ### State Commercial Banks (commercial banking)

# %%
sample_banks = pd.read_csv("data/min_vol_sample_State_Commercial_Banks.csv")
cos_sim_banks = pd.read_csv("data/min_vol_cos_sim_State_Commercial_Banks.csv")
factor_model_banks = pd.read_csv("data/min_vol_factor_model_State_Commercial_Banks.csv")

# %%
sample_banks = sample_banks.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
cos_sim_banks = cos_sim_banks.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)
factor_model_banks = factor_model_banks.sort_values(by=["Weight"], ascending=False).reset_index(drop=True)

# %%
columns = pd.MultiIndex.from_product([['Sample Estimate', 'Cosine Similarity Estimate', 'Factor Model Estimate'], 
                                      ['Company Name', 'Weight']])
banks = pd.concat([pd.concat([sample_banks, cos_sim_banks], axis=1), factor_model_banks], axis=1)
banks.columns = columns
Same = (set(sample_banks.Company_Name) & set(cos_sim_banks.Company_Name)) & set(factor_model_banks.Company_Name)

# %%
banks.style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_ea93d_row0_col0, #T_ea93d_row0_col1, #T_ea93d_row0_col2, #T_ea93d_row0_col3, #T_ea93d_row0_col4, #T_ea93d_row0_col5, #T_ea93d_row1_col0, #T_ea93d_row1_col1, #T_ea93d_row1_col2, #T_ea93d_row1_col3, #T_ea93d_row1_col4, #T_ea93d_row1_col5, #T_ea93d_row2_col0, #T_ea93d_row2_col1, #T_ea93d_row2_col2, #T_ea93d_row2_col3, #T_ea93d_row2_col4, #T_ea93d_row2_col5, #T_ea93d_row3_col0, #T_ea93d_row3_col1, #T_ea93d_row3_col3, #T_ea93d_row3_col4, #T_ea93d_row3_col5, #T_ea93d_row4_col0, #T_ea93d_row4_col1, #T_ea93d_row4_col2, #T_ea93d_row4_col3, #T_ea93d_row4_col4, #T_ea93d_row4_col5, #T_ea93d_row5_col1, #T_ea93d_row5_col2, #T_ea93d_row5_col3, #T_ea93d_row5_col4, #T_ea93d_row5_col5, #T_ea93d_row6_col0, #T_ea93d_row6_col1, #T_ea93d_row6_col2, #T_ea93d_row6_col3, #T_ea93d_row6_col4, #T_ea93d_row6_col5, #T_ea93d_row7_col0, #T_ea93d_row7_col1, #T_ea93d_row7_col2, #T_ea93d_row7_col3, #T_ea93d_row7_col4, #T_ea93d_row7_col5, #T_ea93d_row8_col0, #T_ea93d_row8_col1, #T_ea93d_row8_col2, #T_ea93d_row8_col3, #T_ea93d_row8_col4, #T_ea93d_row8_col5, #T_ea93d_row9_col0, #T_ea93d_row9_col1, #T_ea93d_row9_col2, #T_ea93d_row9_col3, #T_ea93d_row9_col4, #T_ea93d_row9_col5, #T_ea93d_row10_col0, #T_ea93d_row10_col1, #T_ea93d_row10_col2, #T_ea93d_row10_col3, #T_ea93d_row10_col4, #T_ea93d_row10_col5, #T_ea93d_row11_col0, #T_ea93d_row11_col1, #T_ea93d_row11_col2, #T_ea93d_row11_col3, #T_ea93d_row11_col4, #T_ea93d_row11_col5, #T_ea93d_row12_col0, #T_ea93d_row12_col1, #T_ea93d_row12_col2, #T_ea93d_row12_col3, #T_ea93d_row12_col4, #T_ea93d_row12_col5, #T_ea93d_row13_col0, #T_ea93d_row13_col1, #T_ea93d_row13_col2, #T_ea93d_row13_col3, #T_ea93d_row13_col4, #T_ea93d_row13_col5, #T_ea93d_row14_col0, #T_ea93d_row14_col1, #T_ea93d_row14_col2, #T_ea93d_row14_col3, #T_ea93d_row14_col4, #T_ea93d_row14_col5, #T_ea93d_row15_col0, #T_ea93d_row15_col1, #T_ea93d_row15_col2, #T_ea93d_row15_col3, #T_ea93d_row15_col4, #T_ea93d_row15_col5, #T_ea93d_row16_col0, #T_ea93d_row16_col1, #T_ea93d_row16_col2, #T_ea93d_row16_col3, #T_ea93d_row16_col4, #T_ea93d_row16_col5, #T_ea93d_row17_col0, #T_ea93d_row17_col1, #T_ea93d_row17_col2, #T_ea93d_row17_col3, #T_ea93d_row17_col4, #T_ea93d_row17_col5, #T_ea93d_row18_col0, #T_ea93d_row18_col1, #T_ea93d_row18_col2, #T_ea93d_row18_col3, #T_ea93d_row18_col4, #T_ea93d_row18_col5, #T_ea93d_row19_col0, #T_ea93d_row19_col1, #T_ea93d_row19_col2, #T_ea93d_row19_col3, #T_ea93d_row19_col4, #T_ea93d_row19_col5, #T_ea93d_row20_col0, #T_ea93d_row20_col1, #T_ea93d_row20_col2, #T_ea93d_row20_col3, #T_ea93d_row20_col4, #T_ea93d_row20_col5, #T_ea93d_row21_col0, #T_ea93d_row21_col1, #T_ea93d_row21_col2, #T_ea93d_row21_col3, #T_ea93d_row21_col4, #T_ea93d_row21_col5, #T_ea93d_row22_col0, #T_ea93d_row22_col1, #T_ea93d_row22_col2, #T_ea93d_row22_col3, #T_ea93d_row22_col5, #T_ea93d_row23_col0, #T_ea93d_row23_col1, #T_ea93d_row23_col2, #T_ea93d_row23_col3, #T_ea93d_row23_col4, #T_ea93d_row23_col5, #T_ea93d_row24_col0, #T_ea93d_row24_col1, #T_ea93d_row24_col2, #T_ea93d_row24_col3, #T_ea93d_row24_col4, #T_ea93d_row24_col5, #T_ea93d_row25_col0, #T_ea93d_row25_col1, #T_ea93d_row25_col2, #T_ea93d_row25_col3, #T_ea93d_row25_col4, #T_ea93d_row25_col5, #T_ea93d_row26_col0, #T_ea93d_row26_col1, #T_ea93d_row26_col2, #T_ea93d_row26_col3, #T_ea93d_row26_col4, #T_ea93d_row26_col5, #T_ea93d_row27_col0, #T_ea93d_row27_col1, #T_ea93d_row27_col2, #T_ea93d_row27_col3, #T_ea93d_row27_col4, #T_ea93d_row27_col5, #T_ea93d_row28_col0, #T_ea93d_row28_col1, #T_ea93d_row28_col2, #T_ea93d_row28_col3, #T_ea93d_row28_col4, #T_ea93d_row28_col5, #T_ea93d_row29_col0, #T_ea93d_row29_col1, #T_ea93d_row29_col2, #T_ea93d_row29_col3, #T_ea93d_row29_col4, #T_ea93d_row29_col5, #T_ea93d_row30_col0, #T_ea93d_row30_col1, #T_ea93d_row30_col2, #T_ea93d_row30_col3, #T_ea93d_row30_col4, #T_ea93d_row30_col5, #T_ea93d_row31_col0, #T_ea93d_row31_col1, #T_ea93d_row31_col2, #T_ea93d_row31_col3, #T_ea93d_row31_col4, #T_ea93d_row31_col5, #T_ea93d_row32_col0, #T_ea93d_row32_col1, #T_ea93d_row32_col2, #T_ea93d_row32_col3, #T_ea ...
#   color: black;
# }
# #T_ea93d_row3_col2, #T_ea93d_row5_col0, #T_ea93d_row22_col4 {
#   color: blue;
# }
# </style>
# <table id="T_ea93d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea93d_level0_col0" class="col_heading level0 col0" colspan="2">Sample Estimate</th>
#       <th id="T_ea93d_level0_col2" class="col_heading level0 col2" colspan="2">Cosine Similarity Estimate</th>
#       <th id="T_ea93d_level0_col4" class="col_heading level0 col4" colspan="2">Factor Model Estimate</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ea93d_level1_col0" class="col_heading level1 col0" >Company Name</th>
#       <th id="T_ea93d_level1_col1" class="col_heading level1 col1" >Weight</th>
#       <th id="T_ea93d_level1_col2" class="col_heading level1 col2" >Company Name</th>
#       <th id="T_ea93d_level1_col3" class="col_heading level1 col3" >Weight</th>
#       <th id="T_ea93d_level1_col4" class="col_heading level1 col4" >Company Name</th>
#       <th id="T_ea93d_level1_col5" class="col_heading level1 col5" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea93d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea93d_row0_col0" class="data row0 col0" >INVESTAR HOLDING CORP</td>
#       <td id="T_ea93d_row0_col1" class="data row0 col1" >0.194400</td>
#       <td id="T_ea93d_row0_col2" class="data row0 col2" >BANNER CORP</td>
#       <td id="T_ea93d_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_ea93d_row0_col4" class="data row0 col4" >CAROLINA TRUST BANCSHARES, INC.</td>
#       <td id="T_ea93d_row0_col5" class="data row0 col5" >0.060340</td>
#     </tr>
#     <tr>
#       <th id="T_ea93d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea93d_row1_col0" class="data row1 col0" >GUARANTY FEDERAL BANCSHARES INC</td>
#       <td id="T_ea93d_row1_col1" class="data row1 col1" >0.177240</td>
#       <td id="T_ea93d_row1_col2" class="data row1 col2" >INVESTAR HOLDING CORP</td>
#       <td id="T_ea93d_row1_col3" class="data row1 col3" >0.167890</td>
#       <td id="T_ea93d_row1_col4" class="data row1 col4" >SUMMIT FINANCIAL GROUP INC</td>
#       <td id="T_ea93d_row1_col5" class="data row1 col5" >0.050770</td>
#     </tr>
#     <tr>
#       <th id="T_ea93d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea93d_row2_col0" class="data row2 col0" >VILLAGE BANK & TRUST FINANCIAL CORP.</td>
#       <td id="T_ea93d_row2_col1" class="data row2 col1" >0.139940</td>
#       <td id="T_ea93d_row2_col2" class="data row2 col2" >CITIZENS & NORTHERN CORP</td>
#       <td id="T_ea93d_row2_col3" class="data row2 col3" >0.113050</td>
#       <td id="T_ea93d_row2_col4" c

# %% [markdown]
# ### Crude Petroleum and Natural Gas
# Since there is no optimal portfolio generating from cosine similarity estimate or factor model estimate for the Crude Petroleum and Natural Gas industry, we only display the portfolio weights for sample estimate.

# %%
sample_crude = pd.read_csv("data/min_vol_sample_Crude_Petroleum_and_Natural_Gas.csv")
columns = pd.MultiIndex.from_product([['Sample Estimate'], 
                                      ['Company Name', 'Weight']])
sample_crude.columns = columns
sample_crude
#cos_sim_crude = pd.read_csv("data/min_vol_cos_sim_Crude_Petroleum_and_Natural_Gas.csv")
#factor_model_crude = pd.read_csv("data/min_vol_factor_model_Crude_Petroleum_and_Natural_Gas.csv")
# Out:
#                                  Sample Estimate
#                                     Company Name   Weight
# 0                              ROSETTA STONE INC  0.01647
# 1                              MICROSTRATEGY INC  0.02160
# 2                          AVID TECHNOLOGY, INC.  0.00129
# 3   ENDURANCE INTERNATIONAL GROUP HOLDINGS, INC.  0.02554
# 4                                    ZEDGE, INC.  0.01792
# 5                                    ORACLE CORP  0.09170
# 6                            ACI WORLDWIDE, INC.  0.11314
# 7                                      QUMU CORP  0.05153
# 8                                   QUALYS, INC.  0.06668
# 9                          COMMVAULT SYSTEMS INC  0.07381
# 10                            BLACK KNIGHT, INC.  0.20000
# 11                                LIVEPERSON INC  0.01519
# 12                   NUANCE COMMUNICATIONS, INC.  0.08608
# 13                                AWARE INC /MA/  0.20000
# 14                                       MAJESCO  0.01906

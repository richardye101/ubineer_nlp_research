# %% [markdown]
# ## Document Embedding Results
#
# The table below illustrates an overview of the results of all the techniques we explored to create document embeddings.

# %% [markdown]
# <!-- |Embedding Technique | Prepackaged Software(Recall) |  Crude Petroleum and Natural Gas(Recall) |  Pharmaceutical Preparations(Recall) | Real Estate Investment Trusts(Recall) | State Commercial Banks(Recall) | Weighted Average(Recall)
# |--------------------|------------------------------|------------------------------|------------------------------|------------------------------|------------------------------|------------------------------|
# |TF-IDF| 0.89 | 0.94 | 0.75 | 0.94 | 0.95 | 0.91 | 0.89 | 0.91 |
# |N-grams - Cosine Similarity|  0.85 | 0.93  |  0.76 |  0.95 |  0.94 |  0.91 |
# |POS Tagging - Cosine Similarity| 0.86  |  0.96 |  0.91 |  0.97 | 0.97  | 0.95  |
# |Word2Vec| 0.76 | 0.95 | 0.46 | 0.85 | 0.82 | 0.82 | 0.77 | 0.82 |
# |Doc2Vec| 0.88 | 0.97 | 0.86 | 0.91 | 0.94 | 0.92 | 0.91 | 0.92 |
# |TwoTowers| 0.67  | 0.56  |0.60   |0.68   |0.65   |0.63   |
# |Universal Sentence Encoder| 0.83  |0.96  |0.90   |0.96   |0.96 |0.94 | -->

# %%
cols = ["Prepackaged Software(Recall)", "Crude Petroleum and Natural Gas(Recall)",
        "Pharmaceutical Preparations(Recall)", "Real Estate Investment Trusts(Recall)", "State Commercial Banks(Recall)",
        "Weighted Average(Recall)"]
data = [[0.89,0.94,0.75,0.94,0.95,0.91],
[0.85,0.93,0.76,0.95,0.94,0.91],
[0.86,0.96,0.91,0.97,0.97,0.95],
[0.76,0.95,0.46,0.85,0.82,0.82],
[0.88,0.97,0.86,0.91,0.94,0.92],
[0.67,0.56,0.60,0.68,0.65,0.63],
[0.83,0.96,0.90,0.96,0.96,0.94]]
methods = ["TF-IDF", "N-grams - Cosine Similarity", "POS Tagging - Cosine Similarity", "Word2Vec",
           "Doc2Vec","TwoTowers", "Universal Sentence Encoder"]

import pandas as pd
df = pd.DataFrame(data, index = methods, columns = cols).rename_axis("Embedding Technique")

import seaborn as sns
cm = sns.light_palette("#5CCDC6", n_colors = 35, as_cmap=True)

df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_b2513_row0_col0, #T_b2513_row2_col2, #T_b2513_row2_col3, #T_b2513_row2_col4, #T_b2513_row2_col5, #T_b2513_row4_col1 {
#   background-color: #5ccdc6;
#   color: #000000;
# }
# #T_b2513_row0_col1 {
#   background-color: #66d0c9;
#   color: #000000;
# }
# #T_b2513_row0_col2 {
#   background-color: #8fdad6;
#   color: #000000;
# }
# #T_b2513_row0_col3 {
#   background-color: #6ad1ca;
#   color: #000000;
# }
# #T_b2513_row0_col4, #T_b2513_row1_col3 {
#   background-color: #65cfc9;
#   color: #000000;
# }
# #T_b2513_row0_col5, #T_b2513_row1_col5 {
#   background-color: #6dd2cb;
#   color: #000000;
# }
# #T_b2513_row1_col0 {
#   background-color: #76d4ce;
#   color: #000000;
# }
# #T_b2513_row1_col1, #T_b2513_row1_col4, #T_b2513_row4_col4 {
#   background-color: #69d1ca;
#   color: #000000;
# }
# #T_b2513_row1_col2 {
#   background-color: #8bd9d5;
#   color: #000000;
# }
# #T_b2513_row2_col0 {
#   background-color: #6fd2cc;
#   color: #000000;
# }
# #T_b2513_row2_col1, #T_b2513_row6_col1, #T_b2513_row6_col2 {
#   background-color: #5fcec7;
#   color: #000000;
# }
# #T_b2513_row3_col0 {
#   background-color: #b0e3e0;
#   color: #000000;
# }
# #T_b2513_row3_col1 {
#   background-color: #63cfc8;
#   color: #000000;
# }
# #T_b2513_row3_col2, #T_b2513_row5_col0, #T_b2513_row5_col1, #T_b2513_row5_col3, #T_b2513_row5_col4, #T_b2513_row5_col5 {
#   background-color: #eaf2f2;
#   color: #000000;
# }
# #T_b2513_row3_col3 {
#   background-color: #97dcd8;
#   color: #000000;
# }
# #T_b2513_row3_col4 {
#   background-color: #9fdfdb;
#   color: #000000;
# }
# #T_b2513_row3_col5 {
#   background-color: #96dcd8;
#   color: #000000;
# }
# #T_b2513_row4_col0 {
#   background-color: #62cfc8;
#   color: #000000;
# }
# #T_b2513_row4_col2 {
#   background-color: #6cd1cb;
#   color: #000000;
# }
# #T_b2513_row4_col3 {
#   background-color: #79d5cf;
#   color: #000000;
# }
# #T_b2513_row4_col5 {
#   background-color: #69d0ca;
#   color: #000000;
# }
# #T_b2513_row5_col2 {
#   background-color: #bee7e4;
#   color: #000000;
# }
# #T_b2513_row6_col0 {
#   background-color: #82d7d2;
#   color: #000000;
# }
# #T_b2513_row6_col3, #T_b2513_row6_col4, #T_b2513_row6_col5 {
#   background-color: #60cec7;
#   color: #000000;
# }
# </style>
# <table id="T_b2513">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2513_level0_col0" class="col_heading level0 col0" >Prepackaged Software(Recall)</th>
#       <th id="T_b2513_level0_col1" class="col_heading level0 col1" >Crude Petroleum and Natural Gas(Recall)</th>
#       <th id="T_b2513_level0_col2" class="col_heading level0 col2" >Pharmaceutical Preparations(Recall)</th>
#       <th id="T_b2513_level0_col3" class="col_heading level0 col3" >Real Estate Investment Trusts(Recall)</th>
#       <th id="T_b2513_level0_col4" class="col_heading level0 col4" >State Commercial Banks(Recall)</th>
#       <th id="T_b2513_level0_col5" class="col_heading level0 col5" >Weighted Average(Recall)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embedding Technique</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2513_level0_row0" class="row_heading level0 row0" >TF-IDF</th>
#       <td id="T_b2513_row0_col0" class="data row0 col0" >0.890000</td>
#       <td id="T_b2513_row0_col1" class="data row0 col1" >0.940000</td>
#       <td id="T_b2513_row0_col2" class="data row0 col2" >0.750000</td>
#       <td id="T_b2513_row0_col3" class="data row0 col3" >0.940000</td>
#       <td id="T_b2513_row0_col4" class="data row0 col4" >0.950000</td>
#       <td id="T_b2513_row0_col5" class="data row0 col5" >0.910000</td>
#     </tr>
#     <tr>
#       <th id="T_b2513_level0_row1" class="row_heading level0 row1" >N-grams - Cosine Similarity</th>
#       <td id="T_b2513_row1_col0" class="data row1 col0" >0.850000</td>
#       <td id="T_b2513_row1_col1" class="data row1 col1" >0.930000</td>
#       <td id="T_b2513_row1_col2" class="data row1 col2" >0.760000</td>
#       <td id="T_b2513_row1_col3" class="data row1 col3" >0.950000</td>
#       <td id="T_b2513_row1_col4" class="data row1 col4" >0.940000</td>
#       <td id="T_b2513_row1_col5" class="data row1 col5" >0.910000</td>
#     </tr>
#     <tr>
#       <th id="T_b2513_level0_row2" class="row_heading level0 row2" >POS Tagging - Cosine Similarity</th>
#       <td id="T_b2513_row2_col0" class="data row2 col0" >0.860000</td>
#       <td id="T_b2513_row2_col1" class="data row2 col1" >0.960000</td>
#       <td id="T_b2513_row2_col2" class="data row2 col2" >0.910000</td>
#       <td id="T_b2513_row2_col3" class="data row2 col3" >0.970000</td>
#       <td id="T_b2513_row2_col4" class="data row2 col4" >0.970000</td>
#       <td id="T_b2513_row2_col5" class="data row2 col5" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_b2513_level0_row3" class="row_heading level0 row3" >Word2Vec</th>
#       <td id="T_b2513_row3_col0" class="data row3 col0" >0.760000</td>
#       <td id="T_b2513_row3_col1" class="data row3 col1" >0.950000</td>
#       <td id="T_b2513_row3_col2" class="data row3 col2" >0.460000</td>
#       <td id="T_b2513_row3_col3" class="data row3 col3" >0.850000</td>
#       <td id="T_b2513_row3_col4" class="data row3 col4" >0.820000</td>
#       <td id="T_b2513_row3_col5" class="data row3 col5" >0.820000</td>
#     </tr>
#     <tr>
#       <th id="T_b2513_level0_row4" class="row_heading level0 row4" >Doc2Vec</th>
#       <td id="T_b2513_row4_col0" class="data row4 col0" >0.880000</td>
#       <td id="T_b2513_row4_col1" class="data row4 col1" >0.970000</td>
#       <td id="T_b2513_row4_col2" class="data row4 col2" >0.860000</td>
#       <td id="T_b2513_row4_col3" class="data row4 col3" >0.910000</td>
#       <td id="T_b2513_row4_col4" class="data row4 col4" >0.940000</td>
#       <td id="T_b2513_row4_col5" class="data row4 col5" >0.920000</td>
#     </tr>
#     <tr>
#       <th id="T_b2513_level0_row5" class="row_heading level0 row5" >TwoTowers</th>
#       <td id="T_b2513_row5_col0" class="data row5 col0" >0.670000</td>
#       <td id="T_b2513_row5_col1" class="data row5 col1" >0.560000</td>
#       <td id="T_b2513_row5_col2" class="data row5 col2" >0.600000</td>
#       <td id="T_b2513_row5_col3" class="data row5 col3" >0.680000</td>
#       <td id="T_b2513_row5_col4" class="data row5 col4" >0.650000</td>
#       <td id="T_b2513_row5_col5" class="data row5 col5" >0.630000</td>
#     </tr>
#     <tr>
#       <th id="T_b2513_level0_row6" class="row_heading level0 row6" >Universal Sentence Encoder</th>
#       <td id="T_b2513_row6_col0" class="data row6 col0" >0.830000</td>
#       <td id="T_b2513_row6_col1" class="data row6 col1" >0.960000</td>
#       <td id="T_b2513_row6_col2" class="data row6 col2" >0.900000</td>
#       <td id="T_b2513_row6_col3" class="data row6 col3" >0.960000</td>
#       <td id="T_b2513_row6_col4" class="data row6 col4" >0.960000</td>
#       <td id="T_b2513_row6_col5" class="data row6 col5" >0.940000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Conclusion
# To be added when we have all results.
# probably conclude that most of our model done well and is good at classifying xxx category.

# %%
import sys
sys.path.insert(0, '..')
# %load_ext autoreload
# %autoreload 2
# %aimport std_func

# Hide warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Estimates from Cosine Similarity
# We want to evaluate the feasibility of constructing optimized portfolios with the word embedding results. Our first estimate on the textual analysis is generating optimal portfolios using cosine similarity distances. We use the cosine similarity distance as correlation and sample return standard deviation to calculate the covariance estimate. We will compare the results at the end of this section to determine the feasibility.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
r_selected = pd.read_csv("data/filtered_r.csv")
# get the mean of all 
r_selected.set_index("name", inplace = True)
mu = r_selected.mean(axis = 1)
# compute the covariance matrix 
cov = r_selected.T.cov()

# %% [markdown]
# ### Cosine Similarity Distances
# We conduct cosine similarity analysis with 2-to-4 grams embeddings on the business description of each company for all top 5 SIC industry. First, we generate the words counting matrix and perform cosine similarity anlaysis to calculate the distances, which will be used as the correlation between companies in the next step for generating covarince estimate.

# %%
df = pd.read_csv('../data/preprocessed.csv',
                 usecols = ['reportingDate', 'name', 'CIK',
                           'coDescription_stopwords', 'SIC', 'SIC_desc'])
df = df.set_index(df.name)

# %% [markdown]
# #### Words Count
# For this cosine similarity analysis, we generate sequences of 2 to 4 words as one term and only select the top 600 terms by frequency.

# %%
from sklearn.feature_extraction.text import CountVectorizer

Vectorizer = CountVectorizer(ngram_range = (2,4), 
                             max_features = 600)

count_data = Vectorizer.fit_transform(df['coDescription_stopwords'])
wordsCount = pd.DataFrame(count_data.toarray(),columns=Vectorizer.get_feature_names())
wordsCount = wordsCount.set_index(df['name'])
wordsCount
# Out:
#                                                   ability make  \
# name
# MONGODB, INC.                                                0
# SALESFORCE COM INC                                           0
# SPLUNK INC                                                   0
# OKTA, INC.                                                   0
# VEEVA SYSTEMS INC                                            0
# ...                                                        ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.             0
# CYCLACEL PHARMACEUTICALS, INC.                               0
# ZOETIS INC.                                                  0
# STAG INDUSTRIAL, INC.                                        0
# EQUINIX INC                                                  0
#
#                                                   accounting standard  \
# name
# MONGODB, INC.                                                       0
# SALESFORCE COM INC                                                  0
# SPLUNK INC                                                          0
# OKTA, INC.                                                          0
# VEEVA SYSTEMS INC                                                  12
# ...                                                               ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                    0
# CYCLACEL PHARMACEUTICALS, INC.                                      0
# ZOETIS INC.                                                        17
# STAG INDUSTRIAL, INC.                                               0
# EQUINIX INC                                                         0
#
#                                                   acquire property  act act  \
# name
# MONGODB, INC.                                                    0        0
# SALESFORCE COM INC                                               0        0
# SPLUNK INC                                                       0        0
# OKTA, INC.                                                       0        0
# VEEVA SYSTEMS INC                                                0        1
# ...                                                            ...      ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                 1        0
# CYCLACEL PHARMACEUTICALS, INC.                                   0        0
# ZOETIS INC.                                                      0        0
# STAG INDUSTRIAL, INC.                                            1        0
# EQUINIX INC                                                      0        0
#
#                                                   act amended  \
# name
# MONGODB, INC.                                               0
# SALESFORCE COM INC                                          0
# SPLUNK INC                                                  1
# OKTA, INC.                                                  0
# VEEVA SYSTEMS INC                                           4
# ...                                                       ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.            0
# CYCLACEL PHARMACEUTICALS, INC.                              0
# ZOETIS INC.                                                 0
# STAG INDUSTRIAL, INC.                                       1
# EQUINIX INC                                                 2
#
#                                                   additional information  \
# name
# MONGODB, INC.                                                          0
# SALESFORCE COM INC                                                     0
# SPLUNK INC                                                             2
# OKTA, INC.                                                             1
# VEEVA SYSTEMS INC                                                      1
# ...                                                                  ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                       1
# CYCLACEL PHARMACEUTICALS, INC.                                         1
# ZOETIS INC.                                                           12
# STAG INDUSTRIAL, INC.                                                  0
# EQUINIX INC                                                            0
#
#                                                   adequately capitalized  \
# name
# MONGODB, INC.                                                          0
# SALESFORCE COM INC                                                     0
# SPLUNK INC                                                             0
# OKTA, INC.                                                             0
# VEEVA SYSTEMS INC                                                      0
# ...                                                                  ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                       0
# CYCLACEL PHARMACEUTICALS, INC.                                         0
# ZOETIS INC.                                                            0
# STAG INDUSTRIAL, INC.                                                  0
# EQUINIX INC                                                            0
#
#                                                   adverse effect  \
# name
# MONGODB, INC.                                                  0
# SALESFORCE COM INC                                             0
# SPLUNK INC                                                     0
# OKTA, INC.                                                     0
# VEEVA SYSTEMS INC                                              7
# ...                                                          ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.               1
# CYCLACEL PHARMACEUTICALS, INC.                                 1
# ZOETIS INC.                                                    3
# STAG INDUSTRIAL, INC.                                          1
# EQUINIX INC                                                    0
#
#                                                   adverse effect business  \
# name
# MONGODB, INC.                                                           0
# SALESFORCE COM INC                                                      0
# SPLUNK INC                                                              0
# OKTA, INC.                                                              0
# VEEVA SYSTEMS INC                                                       4
# ...                                                                   ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                        0
# CYCLACEL PHARMACEUTICALS, INC.                                          0
# ZOETIS INC.                                                             0
# STAG INDUSTRIAL, INC.                                                   1
# EQUINIX INC                                                             0
#
#                                                   adverse event  ...  \
# name                                                             ...
# MONGODB, INC.                                                 0  ...
# SALESFORCE COM INC                                            0  ...
# SPLUNK INC                                                    0  ...
# OKTA, INC.                                                    0  ...
# VEEVA SYSTEMS INC                                             0  ...
# ...                                                         ...  ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0  ...
# CYCLACEL PHARMACEUTICALS, INC.                                1  ...
# ZOETIS INC.                                                   0  ...
# STAG INDUSTRIAL, INC.                                         0  ...
# EQUINIX INC                                                   0  ...
#
#                                                   wa million  \
# name
# MONGODB, INC.                                              0
# SALESFORCE COM INC                                         0
# SPLUNK INC                                                 0
# OKTA, INC.                                                 0
# VEEVA SYSTEMS INC                                         18
# ...                                                      ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.           0
# CYCLACEL PHARMACEUTICALS, INC.                             0
# ZOETIS INC.                                               20
# STAG INDUSTRIAL, INC.                                      0
# EQUINIX INC                                                0
#
#                                                   weighted average  \
# name
# MONGODB, INC.                                                    0
# SALESFORCE COM INC                                               0
# SPLUNK INC                                                       0
# OKTA, INC.                                                       0
# VEEVA SYSTEMS INC                                                4
# ...                                                            ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                 0
# CYCLACEL PHARMACEUTICALS, INC.                                   0
# ZOETIS INC.                                                      5
# STAG INDUSTRIAL, INC.                                            0
# EQUINIX INC                                                      0
#
#                                                   well capitalized  \
# name
# MONGODB, INC.                                                    0
# SALESFORCE COM INC                                               0
# SPLUNK INC                                                       0
# OKTA, INC.                                                       0
# VEEVA SYSTEMS INC                                                0
# ...                                                            ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                 0
# CYCLACEL PHARMACEUTICALS, INC.                                   0
# ZOETIS INC.                                                      0
# STAG INDUSTRIAL, INC.                                            0
# EQUINIX INC                                                      0
#
#                                                   wholly owned  \
# name
# MONGODB, INC.                                                0
# SALESFORCE COM INC                                           0
# SPLUNK INC                                                   0
# OKTA, INC.                                                   0
# VEEVA SYSTEMS INC                                            0
# ...                                                        ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.             0
# CYCLACEL PHARMACEUTICALS, INC.                               0
# ZOETIS INC.                                                  1
# STAG INDUSTRIAL, INC.                                        0
# EQUINIX INC                                                  0
#
#                                                   wholly owned subsidiary  \
# name
# MONGODB, INC.                                                           0
# SALESFORCE COM INC                                                      0
# SPLUNK INC                                                              0
# OKTA, INC.                                                              0
# VEEVA SYSTEMS INC                                                       0
# ...                                                                   ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                        0
# CYCLACEL PHARMACEUTICALS, INC.                                          0
# ZOETIS INC.                                                             1
# STAG INDUSTRIAL, INC.                                                   0
# EQUINIX INC                                                             0
#
#                                                   wide range  within day  \
# name
# MONGODB, INC.                                              3           0
# SALESFORCE COM INC                                         0           0
# SPLUNK INC                                                 0           0
# OKTA, INC.                                                 1           0
# VEEVA SYSTEMS INC                                          0           1
# ...                                                      ...         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.           0           0
# CYCLACEL PHARMACEUTICALS, INC.                             0           1
# ZOETIS INC.                                                0           2
# STAG INDUSTRIAL, INC.                                      0           0
# EQUINIX INC                                                0           0
#
#                                                   working interest  \
# name
# MONGODB, INC.                                                    0
# SALESFORCE COM INC                                               0
# SPLUNK INC                                                       0
# OKTA, INC.                                                       0
# VEEVA SYSTEMS INC                                                0
# ...                                                            ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                 0
# CYCLACEL PHARMACEUTICALS, INC.                                   0
# ZOETIS INC.                                                      0
# STAG INDUSTRIAL, INC.                                            0
# EQUINIX INC                                                      0
#
#                                                   year ended  \
# name
# MONGODB, INC.                                              5
# SALESFORCE COM INC                                         0
# SPLUNK INC                                                 0
# OKTA, INC.                                                 1
# VEEVA SYSTEMS INC                                        102
# ...                                                      ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.           2
# CYCLACEL PHARMACEUTICALS, INC.                             0
# ZOETIS INC.                                               84
# STAG INDUSTRIAL, INC.                                      2
# EQUINIX INC                                                2
#
#                                                   year ended december
# name
# MONGODB, INC.                                                       0
# SALESFORCE COM INC                                                  0
# SPLUNK INC                                                          0
# OKTA, INC.                                                          0
# VEEVA SYSTEMS INC                                                   0
# ...                                                               ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                    2
# CYCLACEL PHARMACEUTICALS, INC.                                      0
# ZOETIS INC.                                                        83
# STAG INDUSTRIAL, INC.                                               2
# EQUINIX INC                                                         2
#
# [675 rows x 600 columns]

# %% [markdown]
# #### Cosine Similarity Computation

# %%
# Compute Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = pd.DataFrame(cosine_similarity(wordsCount, wordsCount))
cosine_sim = cosine_sim.set_index(df['name'])
cosine_sim.columns = df['name']
cosine_sim
# Out:
# name                                              MONGODB, INC.  \
# name
# MONGODB, INC.                                          1.000000
# SALESFORCE COM INC                                     0.445455
# SPLUNK INC                                             0.610272
# OKTA, INC.                                             0.620961
# VEEVA SYSTEMS INC                                      0.500762
# ...                                                         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.       0.135839
# CYCLACEL PHARMACEUTICALS, INC.                         0.144678
# ZOETIS INC.                                            0.189609
# STAG INDUSTRIAL, INC.                                  0.178397
# EQUINIX INC                                            0.102958
#
# name                                              SALESFORCE COM INC  \
# name
# MONGODB, INC.                                               0.445455
# SALESFORCE COM INC                                          1.000000
# SPLUNK INC                                                  0.635969
# OKTA, INC.                                                  0.455189
# VEEVA SYSTEMS INC                                           0.196053
# ...                                                              ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.            0.201230
# CYCLACEL PHARMACEUTICALS, INC.                              0.145089
# ZOETIS INC.                                                 0.075038
# STAG INDUSTRIAL, INC.                                       0.277952
# EQUINIX INC                                                 0.354856
#
# name                                              SPLUNK INC  OKTA, INC.  \
# name
# MONGODB, INC.                                       0.610272    0.620961
# SALESFORCE COM INC                                  0.635969    0.455189
# SPLUNK INC                                          1.000000    0.665648
# OKTA, INC.                                          0.665648    1.000000
# VEEVA SYSTEMS INC                                   0.274023    0.195672
# ...                                                      ...         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.    0.142041    0.144051
# CYCLACEL PHARMACEUTICALS, INC.                      0.128467    0.170361
# ZOETIS INC.                                         0.136418    0.111937
# STAG INDUSTRIAL, INC.                               0.194072    0.163588
# EQUINIX INC                                         0.273502    0.074624
#
# name                                              VEEVA SYSTEMS INC  \
# name
# MONGODB, INC.                                              0.500762
# SALESFORCE COM INC                                         0.196053
# SPLUNK INC                                                 0.274023
# OKTA, INC.                                                 0.195672
# VEEVA SYSTEMS INC                                          1.000000
# ...                                                             ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.           0.211695
# CYCLACEL PHARMACEUTICALS, INC.                             0.060273
# ZOETIS INC.                                                0.501041
# STAG INDUSTRIAL, INC.                                      0.332207
# EQUINIX INC                                                0.064207
#
# name                                              AUTODESK INC  \
# name
# MONGODB, INC.                                         0.338268
# SALESFORCE COM INC                                    0.418546
# SPLUNK INC                                            0.373142
# OKTA, INC.                                            0.399874
# VEEVA SYSTEMS INC                                     0.079927
# ...                                                        ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.      0.106627
# CYCLACEL PHARMACEUTICALS, INC.                        0.094262
# ZOETIS INC.                                           0.069267
# STAG INDUSTRIAL, INC.                                 0.169739
# EQUINIX INC                                           0.060531
#
# name                                              INTERNATIONAL WESTERN PETROLEUM, INC.  \
# name
# MONGODB, INC.                                                                  0.065380
# SALESFORCE COM INC                                                             0.043515
# SPLUNK INC                                                                     0.019112
# OKTA, INC.                                                                     0.013240
# VEEVA SYSTEMS INC                                                              0.074096
# ...                                                                                 ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                               0.027594
# CYCLACEL PHARMACEUTICALS, INC.                                                 0.010770
# ZOETIS INC.                                                                    0.039015
# STAG INDUSTRIAL, INC.                                                          0.044467
# EQUINIX INC                                                                    0.002205
#
# name                                              DAYBREAK OIL & GAS, INC.  \
# name
# MONGODB, INC.                                                     0.052345
# SALESFORCE COM INC                                                0.064999
# SPLUNK INC                                                        0.073553
# OKTA, INC.                                                        0.093942
# VEEVA SYSTEMS INC                                                 0.030179
# ...                                                                    ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                  0.048087
# CYCLACEL PHARMACEUTICALS, INC.                                    0.025407
# ZOETIS INC.                                                       0.022235
# STAG INDUSTRIAL, INC.                                             0.057905
# EQUINIX INC                                                       0.013749
#
# name                                              ETERNAL SPEECH, INC.  \
# name
# MONGODB, INC.                                                 0.000000
# SALESFORCE COM INC                                            0.000000
# SPLUNK INC                                                    0.000000
# OKTA, INC.                                                    0.000000
# VEEVA SYSTEMS INC                                             0.075713
# ...                                                                ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0.000000
# CYCLACEL PHARMACEUTICALS, INC.                                0.000000
# ZOETIS INC.                                                   0.065917
# STAG INDUSTRIAL, INC.                                         0.000000
# EQUINIX INC                                                   0.000000
#
# name                                              ETERNAL SPEECH, INC.  ...  \
# name                                                                    ...
# MONGODB, INC.                                                 0.000000  ...
# SALESFORCE COM INC                                            0.000000  ...
# SPLUNK INC                                                    0.000000  ...
# OKTA, INC.                                                    0.000000  ...
# VEEVA SYSTEMS INC                                             0.075713  ...
# ...                                                                ...  ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0.000000  ...
# CYCLACEL PHARMACEUTICALS, INC.                                0.000000  ...
# ZOETIS INC.                                                   0.065917  ...
# STAG INDUSTRIAL, INC.                                         0.000000  ...
# EQUINIX INC                                                   0.000000  ...
#
# name                                              OMEGA HEALTHCARE INVESTORS INC  \
# name
# MONGODB, INC.                                                           0.050935
# SALESFORCE COM INC                                                      0.029326
# SPLUNK INC                                                              0.018032
# OKTA, INC.                                                              0.013905
# VEEVA SYSTEMS INC                                                       0.424046
# ...                                                                          ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                        0.284525
# CYCLACEL PHARMACEUTICALS, INC.                                          0.015318
# ZOETIS INC.                                                             0.159082
# STAG INDUSTRIAL, INC.                                                   0.424106
# EQUINIX INC                                                             0.018944
#
# name                                              TABLEAU SOFTWARE INC  \
# name
# MONGODB, INC.                                                 0.630465
# SALESFORCE COM INC                                            0.492079
# SPLUNK INC                                                    0.569939
# OKTA, INC.                                                    0.579884
# VEEVA SYSTEMS INC                                             0.280852
# ...                                                                ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.              0.114080
# CYCLACEL PHARMACEUTICALS, INC.                                0.193458
# ZOETIS INC.                                                   0.327556
# STAG INDUSTRIAL, INC.                                         0.242169
# EQUINIX INC                                                   0.068787
#
# name                                              HORIZON PHARMA PLC  \
# name
# MONGODB, INC.                                               0.436327
# SALESFORCE COM INC                                          0.300027
# SPLUNK INC                                                  0.330028
# OKTA, INC.                                                  0.541775
# VEEVA SYSTEMS INC                                           0.153335
# ...                                                              ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.            0.075274
# CYCLACEL PHARMACEUTICALS, INC.                              0.462759
# ZOETIS INC.                                                 0.148224
# STAG INDUSTRIAL, INC.                                       0.179394
# EQUINIX INC                                                 0.035503
#
# name                                              MERRIMACK PHARMACEUTICALS INC  \
# name
# MONGODB, INC.                                                          0.143385
# SALESFORCE COM INC                                                     0.133831
# SPLUNK INC                                                             0.116923
# OKTA, INC.                                                             0.163709
# VEEVA SYSTEMS INC                                                      0.083683
# ...                                                                         ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                       0.048741
# CYCLACEL PHARMACEUTICALS, INC.                                         0.683597
# ZOETIS INC.                                                            0.051060
# STAG INDUSTRIAL, INC.                                                  0.068313
# EQUINIX INC                                                            0.011838
#
# name                                              REVEN HOUSING REIT, INC.  \
# name
# MONGODB, INC.                                                     0.066598
# SALESFORCE COM INC                                                0.201221
# SPLUNK INC                                                        0.109538
# OKTA, INC.                                                        0.109948
# VEEVA SYSTEMS INC                                                 0.128762
# ...                                                                    ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                  0.578793
# CYCLACEL PHARMACEUTICALS, INC.                                    0.047288
# ZOETIS INC.                                                       0.163391
# STAG INDUSTRIAL, INC.                                             0.407758
# EQUINIX INC                                                       0.043938
#
# name                                              AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.  \
# name
# MONGODB, INC.                                                                             0.135839
# SALESFORCE COM INC                                                                        0.201230
# SPLUNK INC                                                                                0.142041
# OKTA, INC.                                                                                0.144051
# VEEVA SYSTEMS INC                                                                         0.211695
# ...                                                                                            ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                                          1.000000
# CYCLACEL PHARMACEUTICALS, INC.                                                            0.039971
# ZOETIS INC.                                                                               0.136184
# STAG INDUSTRIAL, INC.                                                                     0.471651
# EQUINIX INC                                                                               0.042298
#
# name                                              CYCLACEL PHARMACEUTICALS, INC.  \
# name
# MONGODB, INC.                                                           0.144678
# SALESFORCE COM INC                                                      0.145089
# SPLUNK INC                                                              0.128467
# OKTA, INC.                                                              0.170361
# VEEVA SYSTEMS INC                                                       0.060273
# ...                                                                          ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.                        0.039971
# CYCLACEL PHARMACEUTICALS, INC.                                          1.000000
# ZOETIS INC.                                                             0.035694
# STAG INDUSTRIAL, INC.                                                   0.080139
# EQUINIX INC                                                             0.013121
#
# name                                              ZOETIS INC.  \
# name
# MONGODB, INC.                                        0.189609
# SALESFORCE COM INC                                   0.075038
# SPLUNK INC                                           0.136418
# OKTA, INC.                                           0.111937
# VEEVA SYSTEMS INC                                    0.501041
# ...                                                       ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.     0.136184
# CYCLACEL PHARMACEUTICALS, INC.                       0.035694
# ZOETIS INC.                                          1.000000
# STAG INDUSTRIAL, INC.                                0.207232
# EQUINIX INC                                          0.031911
#
# name                                              STAG INDUSTRIAL, INC.  \
# name
# MONGODB, INC.                                                  0.178397
# SALESFORCE COM INC                                             0.277952
# SPLUNK INC                                                     0.194072
# OKTA, INC.                                                     0.163588
# VEEVA SYSTEMS INC                                              0.332207
# ...                                                                 ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.               0.471651
# CYCLACEL PHARMACEUTICALS, INC.                                 0.080139
# ZOETIS INC.                                                    0.207232
# STAG INDUSTRIAL, INC.                                          1.000000
# EQUINIX INC                                                    0.038365
#
# name                                              EQUINIX INC
# name
# MONGODB, INC.                                        0.102958
# SALESFORCE COM INC                                   0.354856
# SPLUNK INC                                           0.273502
# OKTA, INC.                                           0.074624
# VEEVA SYSTEMS INC                                    0.064207
# ...                                                       ...
# AMERICAN REALTY CAPITAL NEW YORK CITY REIT, INC.     0.042298
# CYCLACEL PHARMACEUTICALS, INC.                       0.013121
# ZOETIS INC.                                          0.031911
# STAG INDUSTRIAL, INC.                                0.038365
# EQUINIX INC                                          1.000000
#
# [675 rows x 675 columns]

# %% [markdown]
# ### Perform Mean-Variance Analysis
# We only use the Pharmaceutical Preparations industry data to generate portfolio based on Mean-Variance Analysis. We calculate the covariance estimate with cosine similarity distance as correlation and the sample standard deviation of returns. Then we use the sample return and estimated covariance to build efficient frontier.

# %%
# !pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: PyPortfolioOpt in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: pandas>=0.19 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.12 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.20.3)
# Requirement already satisfied: scipy<2.0,>=1.3 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.7.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.1.18)
# Requirement already satisfied: scs>=1.1.6 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.0)
# Requirement already satisfied: ecos>=2 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: osqp>=0.4.1 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post5)
# Requirement already satisfied: qdldl in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/lulu/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)

# %%
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import objective_functions
from pypfopt import plotting

# %%
# get the names of the companies in the pharmaceutical preparations industry
Pharm = df[df.SIC == 2834]
Pharm_list = Pharm.index

# %%
# get the companies name that match return data and business description data
SET = (set(Pharm_list) & set(r_selected.index))
LIST = [*SET, ]

# %% [markdown]
# #### Sample Mean for the Pharmaceutical Preparations Industry

# %%
mu_Pharm = mu[LIST]
mu_Pharm
# Out:
# name
# BRISTOL MYERS SQUIBB CO          -0.004359
# ACHAOGEN INC                      0.007742
# MERCK & CO., INC.                 0.013889
# JOHNSON & JOHNSON                 0.007494
# EMERGENT BIOSOLUTIONS INC.        0.019928
#                                     ...
# CYTOMX THERAPEUTICS, INC.         0.022405
# VERASTEM, INC.                    0.054646
# PROPHASE LABS, INC.               0.038154
# INTRA-CELLULAR THERAPIES, INC.   -0.012532
# BIOMARIN PHARMACEUTICAL INC       0.001661
# Length: 124, dtype: float64

# %% [markdown]
# #### Sample Covariance for the Pharmaceutical Preparations Industry

# %%
tmp = cov[LIST].T
cov_Pharm = tmp[LIST]
cov_Pharm
# Out:
# name                            BRISTOL MYERS SQUIBB CO  ACHAOGEN INC  \
# name
# BRISTOL MYERS SQUIBB CO                        0.007213      0.000330
# ACHAOGEN INC                                   0.000330      0.097615
# MERCK & CO., INC.                             -0.000429     -0.001274
# JOHNSON & JOHNSON                              0.001188      0.001111
# EMERGENT BIOSOLUTIONS INC.                     0.003389      0.004648
# ...                                                 ...           ...
# CYTOMX THERAPEUTICS, INC.                      0.000675      0.007474
# VERASTEM, INC.                                 0.000120     -0.003192
# PROPHASE LABS, INC.                           -0.000658     -0.000163
# INTRA-CELLULAR THERAPIES, INC.                 0.005489      0.005616
# BIOMARIN PHARMACEUTICAL INC                    0.001860      0.000741
#
# name                            MERCK & CO., INC.  JOHNSON & JOHNSON  \
# name
# BRISTOL MYERS SQUIBB CO                 -0.000429           0.001188
# ACHAOGEN INC                            -0.001274           0.001111
# MERCK & CO., INC.                        0.002449           0.000408
# JOHNSON & JOHNSON                        0.000408           0.001999
# EMERGENT BIOSOLUTIONS INC.               0.000378           0.001289
# ...                                           ...                ...
# CYTOMX THERAPEUTICS, INC.               -0.000729          -0.000456
# VERASTEM, INC.                           0.001479           0.000553
# PROPHASE LABS, INC.                      0.000186          -0.000886
# INTRA-CELLULAR THERAPIES, INC.          -0.000840           0.000393
# BIOMARIN PHARMACEUTICAL INC              0.001729           0.000470
#
# name                            EMERGENT BIOSOLUTIONS INC.  \
# name
# BRISTOL MYERS SQUIBB CO                           0.003389
# ACHAOGEN INC                                      0.004648
# MERCK & CO., INC.                                 0.000378
# JOHNSON & JOHNSON                                 0.001289
# EMERGENT BIOSOLUTIONS INC.                        0.014517
# ...                                                    ...
# CYTOMX THERAPEUTICS, INC.                         0.001470
# VERASTEM, INC.                                    0.004382
# PROPHASE LABS, INC.                               0.001247
# INTRA-CELLULAR THERAPIES, INC.                   -0.000350
# BIOMARIN PHARMACEUTICAL INC                       0.005165
#
# name                            FORTRESS BIOTECH, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                       0.006592
# ACHAOGEN INC                                  0.012751
# MERCK & CO., INC.                             0.000255
# JOHNSON & JOHNSON                             0.002340
# EMERGENT BIOSOLUTIONS INC.                    0.009880
# ...                                                ...
# CYTOMX THERAPEUTICS, INC.                     0.010868
# VERASTEM, INC.                                0.008851
# PROPHASE LABS, INC.                           0.002921
# INTRA-CELLULAR THERAPIES, INC.                0.007476
# BIOMARIN PHARMACEUTICAL INC                   0.004658
#
# name                            IMPRIMIS PHARMACEUTICALS, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                              -0.004808
# ACHAOGEN INC                                         -0.004221
# MERCK & CO., INC.                                     0.001941
# JOHNSON & JOHNSON                                    -0.000083
# EMERGENT BIOSOLUTIONS INC.                           -0.003178
# ...                                                        ...
# CYTOMX THERAPEUTICS, INC.                             0.005439
# VERASTEM, INC.                                        0.012776
# PROPHASE LABS, INC.                                   0.002455
# INTRA-CELLULAR THERAPIES, INC.                        0.001048
# BIOMARIN PHARMACEUTICAL INC                           0.000078
#
# name                            CELGENE CORP /DE/  EVOKE PHARMA INC  \
# name
# BRISTOL MYERS SQUIBB CO                  0.003344          0.002127
# ACHAOGEN INC                             0.004253          0.020438
# MERCK & CO., INC.                        0.002320          0.002973
# JOHNSON & JOHNSON                        0.000604          0.000905
# EMERGENT BIOSOLUTIONS INC.               0.003870         -0.000724
# ...                                           ...               ...
# CYTOMX THERAPEUTICS, INC.                0.001287          0.007698
# VERASTEM, INC.                           0.007853          0.007315
# PROPHASE LABS, INC.                      0.001003         -0.004589
# INTRA-CELLULAR THERAPIES, INC.           0.004193          0.003609
# BIOMARIN PHARMACEUTICAL INC              0.005231         -0.001490
#
# name                            MANNKIND CORP  ...  RETROPHIN, INC.  \
# name                                           ...
# BRISTOL MYERS SQUIBB CO              0.003973  ...         0.002464
# ACHAOGEN INC                         0.004404  ...         0.004455
# MERCK & CO., INC.                   -0.001314  ...         0.000327
# JOHNSON & JOHNSON                    0.003650  ...        -0.000199
# EMERGENT BIOSOLUTIONS INC.           0.003944  ...         0.004246
# ...                                       ...  ...              ...
# CYTOMX THERAPEUTICS, INC.           -0.003033  ...         0.008169
# VERASTEM, INC.                      -0.016240  ...         0.004890
# PROPHASE LABS, INC.                 -0.004887  ...         0.000444
# INTRA-CELLULAR THERAPIES, INC.       0.017835  ...         0.002292
# BIOMARIN PHARMACEUTICAL INC         -0.004764  ...         0.003291
#
# name                            PROGENICS PHARMACEUTICALS INC  \
# name
# BRISTOL MYERS SQUIBB CO                              0.006694
# ACHAOGEN INC                                         0.012770
# MERCK & CO., INC.                                    0.002057
# JOHNSON & JOHNSON                                   -0.000907
# EMERGENT BIOSOLUTIONS INC.                           0.006365
# ...                                                       ...
# CYTOMX THERAPEUTICS, INC.                            0.005490
# VERASTEM, INC.                                      -0.001409
# PROPHASE LABS, INC.                                  0.006330
# INTRA-CELLULAR THERAPIES, INC.                       0.013523
# BIOMARIN PHARMACEUTICAL INC                          0.009993
#
# name                            ONCOMED PHARMACEUTICALS INC  \
# name
# BRISTOL MYERS SQUIBB CO                            0.002309
# ACHAOGEN INC                                       0.017775
# MERCK & CO., INC.                                  0.000259
# JOHNSON & JOHNSON                                  0.001195
# EMERGENT BIOSOLUTIONS INC.                         0.006316
# ...                                                     ...
# CYTOMX THERAPEUTICS, INC.                          0.008370
# VERASTEM, INC.                                     0.009481
# PROPHASE LABS, INC.                                0.005767
# INTRA-CELLULAR THERAPIES, INC.                     0.018251
# BIOMARIN PHARMACEUTICAL INC                        0.003412
#
# name                            AMICUS THERAPEUTICS INC  \
# name
# BRISTOL MYERS SQUIBB CO                        0.000548
# ACHAOGEN INC                                  -0.001465
# MERCK & CO., INC.                              0.000551
# JOHNSON & JOHNSON                              0.000171
# EMERGENT BIOSOLUTIONS INC.                     0.005443
# ...                                                 ...
# CYTOMX THERAPEUTICS, INC.                      0.005122
# VERASTEM, INC.                                 0.015465
# PROPHASE LABS, INC.                            0.005081
# INTRA-CELLULAR THERAPIES, INC.                 0.003823
# BIOMARIN PHARMACEUTICAL INC                    0.005656
#
# name                            PAIN THERAPEUTICS INC  \
# name
# BRISTOL MYERS SQUIBB CO                      0.000643
# ACHAOGEN INC                                 0.011570
# MERCK & CO., INC.                            0.002230
# JOHNSON & JOHNSON                            0.000104
# EMERGENT BIOSOLUTIONS INC.                   0.000226
# ...                                               ...
# CYTOMX THERAPEUTICS, INC.                    0.016650
# VERASTEM, INC.                               0.016127
# PROPHASE LABS, INC.                          0.001905
# INTRA-CELLULAR THERAPIES, INC.               0.033830
# BIOMARIN PHARMACEUTICAL INC                  0.007392
#
# name                            CYTOMX THERAPEUTICS, INC.  VERASTEM, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                          0.000675        0.000120
# ACHAOGEN INC                                     0.007474       -0.003192
# MERCK & CO., INC.                               -0.000729        0.001479
# JOHNSON & JOHNSON                               -0.000456        0.000553
# EMERGENT BIOSOLUTIONS INC.                       0.001470        0.004382
# ...                                                   ...             ...
# CYTOMX THERAPEUTICS, INC.                        0.024791        0.008002
# VERASTEM, INC.                                   0.008002        0.067026
# PROPHASE LABS, INC.                              0.003151        0.005563
# INTRA-CELLULAR THERAPIES, INC.                   0.009689        0.013702
# BIOMARIN PHARMACEUTICAL INC                      0.000505        0.003811
#
# name                            PROPHASE LABS, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                   -0.000658
# ACHAOGEN INC                              -0.000163
# MERCK & CO., INC.                          0.000186
# JOHNSON & JOHNSON                         -0.000886
# EMERGENT BIOSOLUTIONS INC.                 0.001247
# ...                                             ...
# CYTOMX THERAPEUTICS, INC.                  0.003151
# VERASTEM, INC.                             0.005563
# PROPHASE LABS, INC.                        0.009482
# INTRA-CELLULAR THERAPIES, INC.             0.003694
# BIOMARIN PHARMACEUTICAL INC                0.002136
#
# name                            INTRA-CELLULAR THERAPIES, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                               0.005489
# ACHAOGEN INC                                          0.005616
# MERCK & CO., INC.                                    -0.000840
# JOHNSON & JOHNSON                                     0.000393
# EMERGENT BIOSOLUTIONS INC.                           -0.000350
# ...                                                        ...
# CYTOMX THERAPEUTICS, INC.                             0.009689
# VERASTEM, INC.                                        0.013702
# PROPHASE LABS, INC.                                   0.003694
# INTRA-CELLULAR THERAPIES, INC.                        0.047693
# BIOMARIN PHARMACEUTICAL INC                           0.003155
#
# name                            BIOMARIN PHARMACEUTICAL INC
# name
# BRISTOL MYERS SQUIBB CO                            0.001860
# ACHAOGEN INC                                       0.000741
# MERCK & CO., INC.                                  0.001729
# JOHNSON & JOHNSON                                  0.000470
# EMERGENT BIOSOLUTIONS INC.                         0.005165
# ...                                                     ...
# CYTOMX THERAPEUTICS, INC.                          0.000505
# VERASTEM, INC.                                     0.003811
# PROPHASE LABS, INC.                                0.002136
# INTRA-CELLULAR THERAPIES, INC.                     0.003155
# BIOMARIN PHARMACEUTICAL INC                        0.007078
#
# [124 rows x 124 columns]

# %% [markdown]
# #### Cosine Similarity Distances for the Pharmaceutical Preparations Industry

# %%
tmp = cosine_sim[LIST].drop_duplicates().T
Pharm_cos_sim = tmp[LIST].drop_duplicates()
Pharm_cos_sim
# Out:
# name                            BRISTOL MYERS SQUIBB CO  ACHAOGEN INC  \
# name
# BRISTOL MYERS SQUIBB CO                        1.000000      0.167565
# ACHAOGEN INC                                   0.167565      1.000000
# MERCK & CO., INC.                              0.076844      0.454169
# JOHNSON & JOHNSON                              0.219265      0.268945
# EMERGENT BIOSOLUTIONS INC.                     0.139264      0.732409
# ...                                                 ...           ...
# CYTOMX THERAPEUTICS, INC.                      0.110923      0.709459
# VERASTEM, INC.                                 0.086711      0.454054
# PROPHASE LABS, INC.                            0.084365      0.413496
# INTRA-CELLULAR THERAPIES, INC.                 0.000000      0.500856
# BIOMARIN PHARMACEUTICAL INC                    0.063246      0.310514
#
# name                            MERCK & CO., INC.  JOHNSON & JOHNSON  \
# name
# BRISTOL MYERS SQUIBB CO                  0.076844           0.219265
# ACHAOGEN INC                             0.454169           0.268945
# MERCK & CO., INC.                        1.000000           0.319654
# JOHNSON & JOHNSON                        0.319654           1.000000
# EMERGENT BIOSOLUTIONS INC.               0.499264           0.268713
# ...                                           ...                ...
# CYTOMX THERAPEUTICS, INC.                0.257419           0.096313
# VERASTEM, INC.                           0.461667           0.087458
# PROPHASE LABS, INC.                      0.440841           0.159085
# INTRA-CELLULAR THERAPIES, INC.           0.362780           0.068737
# BIOMARIN PHARMACEUTICAL INC              0.249946           0.038829
#
# name                            EMERGENT BIOSOLUTIONS INC.  \
# name
# BRISTOL MYERS SQUIBB CO                           0.139264
# ACHAOGEN INC                                      0.732409
# MERCK & CO., INC.                                 0.499264
# JOHNSON & JOHNSON                                 0.268713
# EMERGENT BIOSOLUTIONS INC.                        1.000000
# ...                                                    ...
# CYTOMX THERAPEUTICS, INC.                         0.660494
# VERASTEM, INC.                                    0.687453
# PROPHASE LABS, INC.                               0.490940
# INTRA-CELLULAR THERAPIES, INC.                    0.433977
# BIOMARIN PHARMACEUTICAL INC                       0.442907
#
# name                            FORTRESS BIOTECH, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                       0.198965
# ACHAOGEN INC                                  0.187972
# MERCK & CO., INC.                             0.122315
# JOHNSON & JOHNSON                             0.084759
# EMERGENT BIOSOLUTIONS INC.                    0.187552
# ...                                                ...
# CYTOMX THERAPEUTICS, INC.                     0.187698
# VERASTEM, INC.                                0.110909
# PROPHASE LABS, INC.                           0.244591
# INTRA-CELLULAR THERAPIES, INC.                0.162533
# BIOMARIN PHARMACEUTICAL INC                   0.093479
#
# name                            IMPRIMIS PHARMACEUTICALS, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                               0.081771
# ACHAOGEN INC                                          0.286827
# MERCK & CO., INC.                                     0.198084
# JOHNSON & JOHNSON                                     0.143436
# EMERGENT BIOSOLUTIONS INC.                            0.227212
# ...                                                        ...
# CYTOMX THERAPEUTICS, INC.                             0.115192
# VERASTEM, INC.                                        0.165443
# PROPHASE LABS, INC.                                   0.220755
# INTRA-CELLULAR THERAPIES, INC.                        0.168521
# BIOMARIN PHARMACEUTICAL INC                           0.048269
#
# name                            CELGENE CORP /DE/  EVOKE PHARMA INC  \
# name
# BRISTOL MYERS SQUIBB CO                  0.118561          0.000000
# ACHAOGEN INC                             0.706064          0.545191
# MERCK & CO., INC.                        0.540398          0.656778
# JOHNSON & JOHNSON                        0.264122          0.106330
# EMERGENT BIOSOLUTIONS INC.               0.660216          0.592330
# ...                                           ...               ...
# CYTOMX THERAPEUTICS, INC.                0.598642          0.371846
# VERASTEM, INC.                           0.503748          0.506063
# PROPHASE LABS, INC.                      0.433105          0.380576
# INTRA-CELLULAR THERAPIES, INC.           0.487308          0.619926
# BIOMARIN PHARMACEUTICAL INC              0.344930          0.213979
#
# name                            MANNKIND CORP  ...  RETROPHIN, INC.  \
# name                                           ...
# BRISTOL MYERS SQUIBB CO              0.137885  ...         0.044887
# ACHAOGEN INC                         0.753216  ...         0.791710
# MERCK & CO., INC.                    0.526758  ...         0.519562
# JOHNSON & JOHNSON                    0.206595  ...         0.138577
# EMERGENT BIOSOLUTIONS INC.           0.630938  ...         0.710841
# ...                                       ...  ...              ...
# CYTOMX THERAPEUTICS, INC.            0.532764  ...         0.593594
# VERASTEM, INC.                       0.437397  ...         0.541013
# PROPHASE LABS, INC.                  0.427502  ...         0.452910
# INTRA-CELLULAR THERAPIES, INC.       0.528812  ...         0.548398
# BIOMARIN PHARMACEUTICAL INC          0.167146  ...         0.274805
#
# name                            PROGENICS PHARMACEUTICALS INC  \
# name
# BRISTOL MYERS SQUIBB CO                              0.150984
# ACHAOGEN INC                                         0.155118
# MERCK & CO., INC.                                    0.100691
# JOHNSON & JOHNSON                                    0.124973
# EMERGENT BIOSOLUTIONS INC.                           0.130665
# ...                                                       ...
# CYTOMX THERAPEUTICS, INC.                            0.136493
# VERASTEM, INC.                                       0.087552
# PROPHASE LABS, INC.                                  0.093941
# INTRA-CELLULAR THERAPIES, INC.                       0.116686
# BIOMARIN PHARMACEUTICAL INC                          0.053713
#
# name                            ONCOMED PHARMACEUTICALS INC  \
# name
# BRISTOL MYERS SQUIBB CO                            0.081779
# ACHAOGEN INC                                       0.772654
# MERCK & CO., INC.                                  0.393075
# JOHNSON & JOHNSON                                  0.159450
# EMERGENT BIOSOLUTIONS INC.                         0.655421
# ...                                                     ...
# CYTOMX THERAPEUTICS, INC.                          0.802797
# VERASTEM, INC.                                     0.543834
# PROPHASE LABS, INC.                                0.245189
# INTRA-CELLULAR THERAPIES, INC.                     0.559022
# BIOMARIN PHARMACEUTICAL INC                        0.351706
#
# name                            AMICUS THERAPEUTICS INC  \
# name
# BRISTOL MYERS SQUIBB CO                        0.116924
# ACHAOGEN INC                                   0.484584
# MERCK & CO., INC.                              0.217863
# JOHNSON & JOHNSON                              0.102549
# EMERGENT BIOSOLUTIONS INC.                     0.423365
# ...                                                 ...
# CYTOMX THERAPEUTICS, INC.                      0.466211
# VERASTEM, INC.                                 0.273742
# PROPHASE LABS, INC.                            0.159143
# INTRA-CELLULAR THERAPIES, INC.                 0.283731
# BIOMARIN PHARMACEUTICAL INC                    0.340166
#
# name                            PAIN THERAPEUTICS INC  \
# name
# BRISTOL MYERS SQUIBB CO                      0.000000
# ACHAOGEN INC                                 0.327545
# MERCK & CO., INC.                            0.180343
# JOHNSON & JOHNSON                            0.036477
# EMERGENT BIOSOLUTIONS INC.                   0.415782
# ...                                               ...
# CYTOMX THERAPEUTICS, INC.                    0.602611
# VERASTEM, INC.                               0.468821
# PROPHASE LABS, INC.                          0.083333
# INTRA-CELLULAR THERAPIES, INC.               0.434599
# BIOMARIN PHARMACEUTICAL INC                  0.572108
#
# name                            CYTOMX THERAPEUTICS, INC.  VERASTEM, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                          0.110923        0.086711
# ACHAOGEN INC                                     0.709459        0.454054
# MERCK & CO., INC.                                0.257419        0.461667
# JOHNSON & JOHNSON                                0.096313        0.087458
# EMERGENT BIOSOLUTIONS INC.                       0.660494        0.687453
# ...                                                   ...             ...
# CYTOMX THERAPEUTICS, INC.                        1.000000        0.588155
# VERASTEM, INC.                                   0.588155        1.000000
# PROPHASE LABS, INC.                              0.177802        0.296272
# INTRA-CELLULAR THERAPIES, INC.                   0.537050        0.402080
# BIOMARIN PHARMACEUTICAL INC                      0.521243        0.471631
#
# name                            PROPHASE LABS, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                    0.084365
# ACHAOGEN INC                               0.413496
# MERCK & CO., INC.                          0.440841
# JOHNSON & JOHNSON                          0.159085
# EMERGENT BIOSOLUTIONS INC.                 0.490940
# ...                                             ...
# CYTOMX THERAPEUTICS, INC.                  0.177802
# VERASTEM, INC.                             0.296272
# PROPHASE LABS, INC.                        1.000000
# INTRA-CELLULAR THERAPIES, INC.             0.194682
# BIOMARIN PHARMACEUTICAL INC                0.101378
#
# name                            INTRA-CELLULAR THERAPIES, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                               0.000000
# ACHAOGEN INC                                          0.500856
# MERCK & CO., INC.                                     0.362780
# JOHNSON & JOHNSON                                     0.068737
# EMERGENT BIOSOLUTIONS INC.                            0.433977
# ...                                                        ...
# CYTOMX THERAPEUTICS, INC.                             0.537050
# VERASTEM, INC.                                        0.402080
# PROPHASE LABS, INC.                                   0.194682
# INTRA-CELLULAR THERAPIES, INC.                        1.000000
# BIOMARIN PHARMACEUTICAL INC                           0.261603
#
# name                            BIOMARIN PHARMACEUTICAL INC
# name
# BRISTOL MYERS SQUIBB CO                            0.063246
# ACHAOGEN INC                                       0.310514
# MERCK & CO., INC.                                  0.249946
# JOHNSON & JOHNSON                                  0.038829
# EMERGENT BIOSOLUTIONS INC.                         0.442907
# ...                                                     ...
# CYTOMX THERAPEUTICS, INC.                          0.521243
# VERASTEM, INC.                                     0.471631
# PROPHASE LABS, INC.                                0.101378
# INTRA-CELLULAR THERAPIES, INC.                     0.261603
# BIOMARIN PHARMACEUTICAL INC                        1.000000
#
# [124 rows x 124 columns]

# %% [markdown]
# #### Covariance for Cosine Similarity

# %%
sd = pd.DataFrame(np.sqrt(np.diag(np.diagonal(cov_Pharm))))
sd = sd.set_index(cov_Pharm.index)
sd.columns = cov_Pharm.index
cos_sim_cov = pd.DataFrame((np.dot(np.dot(sd, Pharm_cos_sim),sd))).set_index(cov_Pharm.index)
cos_sim_cov.columns = cov_Pharm.index
cos_sim_cov
# Out:
# name                            BRISTOL MYERS SQUIBB CO  ACHAOGEN INC  \
# name
# BRISTOL MYERS SQUIBB CO                        0.007213      0.004446
# ACHAOGEN INC                                   0.004446      0.097615
# MERCK & CO., INC.                              0.000323      0.007021
# JOHNSON & JOHNSON                              0.000833      0.003757
# EMERGENT BIOSOLUTIONS INC.                     0.001425      0.027571
# ...                                                 ...           ...
# CYTOMX THERAPEUTICS, INC.                      0.001483      0.034901
# VERASTEM, INC.                                 0.001907      0.036727
# PROPHASE LABS, INC.                            0.000698      0.012580
# INTRA-CELLULAR THERAPIES, INC.                 0.000000      0.034174
# BIOMARIN PHARMACEUTICAL INC                    0.000452      0.008162
#
# name                            MERCK & CO., INC.  JOHNSON & JOHNSON  \
# name
# BRISTOL MYERS SQUIBB CO                  0.000323           0.000833
# ACHAOGEN INC                             0.007021           0.003757
# MERCK & CO., INC.                        0.002449           0.000707
# JOHNSON & JOHNSON                        0.000707           0.001999
# EMERGENT BIOSOLUTIONS INC.               0.002977           0.001448
# ...                                           ...                ...
# CYTOMX THERAPEUTICS, INC.                0.002006           0.000678
# VERASTEM, INC.                           0.005914           0.001012
# PROPHASE LABS, INC.                      0.002124           0.000693
# INTRA-CELLULAR THERAPIES, INC.           0.003920           0.000671
# BIOMARIN PHARMACEUTICAL INC              0.001041           0.000146
#
# name                            EMERGENT BIOSOLUTIONS INC.  \
# name
# BRISTOL MYERS SQUIBB CO                           0.001425
# ACHAOGEN INC                                      0.027571
# MERCK & CO., INC.                                 0.002977
# JOHNSON & JOHNSON                                 0.001448
# EMERGENT BIOSOLUTIONS INC.                        0.014517
# ...                                                    ...
# CYTOMX THERAPEUTICS, INC.                         0.012530
# VERASTEM, INC.                                    0.021444
# PROPHASE LABS, INC.                               0.005760
# INTRA-CELLULAR THERAPIES, INC.                    0.011419
# BIOMARIN PHARMACEUTICAL INC                       0.004490
#
# name                            FORTRESS BIOTECH, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                       0.003149
# ACHAOGEN INC                                  0.010945
# MERCK & CO., INC.                             0.001128
# JOHNSON & JOHNSON                             0.000706
# EMERGENT BIOSOLUTIONS INC.                    0.004211
# ...                                                ...
# CYTOMX THERAPEUTICS, INC.                     0.005508
# VERASTEM, INC.                                0.005351
# PROPHASE LABS, INC.                           0.004439
# INTRA-CELLULAR THERAPIES, INC.                0.006615
# BIOMARIN PHARMACEUTICAL INC                   0.001466
#
# name                            IMPRIMIS PHARMACEUTICALS, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                               0.001476
# ACHAOGEN INC                                          0.019047
# MERCK & CO., INC.                                     0.002083
# JOHNSON & JOHNSON                                     0.001363
# EMERGENT BIOSOLUTIONS INC.                            0.005819
# ...                                                        ...
# CYTOMX THERAPEUTICS, INC.                             0.003855
# VERASTEM, INC.                                        0.009104
# PROPHASE LABS, INC.                                   0.004569
# INTRA-CELLULAR THERAPIES, INC.                        0.007822
# BIOMARIN PHARMACEUTICAL INC                           0.000863
#
# name                            CELGENE CORP /DE/  EVOKE PHARMA INC  \
# name
# BRISTOL MYERS SQUIBB CO                  0.000981          0.000000
# ACHAOGEN INC                             0.021487          0.036091
# MERCK & CO., INC.                        0.002605          0.006886
# JOHNSON & JOHNSON                        0.001150          0.001007
# EMERGENT BIOSOLUTIONS INC.               0.007748          0.015122
# ...                                           ...               ...
# CYTOMX THERAPEUTICS, INC.                0.009181          0.012405
# VERASTEM, INC.                           0.012703          0.027760
# PROPHASE LABS, INC.                      0.004108          0.007852
# INTRA-CELLULAR THERAPIES, INC.           0.010366          0.028685
# BIOMARIN PHARMACEUTICAL INC              0.002827          0.003814
#
# name                            MANNKIND CORP  ...  RETROPHIN, INC.  \
# name                                           ...
# BRISTOL MYERS SQUIBB CO              0.003698  ...         0.000484
# ACHAOGEN INC                         0.074321  ...         0.031417
# MERCK & CO., INC.                    0.008232  ...         0.003265
# JOHNSON & JOHNSON                    0.002918  ...         0.000787
# EMERGENT BIOSOLUTIONS INC.           0.024008  ...         0.010878
# ...                                       ...  ...              ...
# CYTOMX THERAPEUTICS, INC.            0.026492  ...         0.011871
# VERASTEM, INC.                       0.035763  ...         0.017790
# PROPHASE LABS, INC.                  0.013147  ...         0.005601
# INTRA-CELLULAR THERAPIES, INC.       0.036473  ...         0.015211
# BIOMARIN PHARMACEUTICAL INC          0.004441  ...         0.002936
#
# name                            PROGENICS PHARMACEUTICALS INC  \
# name
# BRISTOL MYERS SQUIBB CO                              0.002623
# ACHAOGEN INC                                         0.009913
# MERCK & CO., INC.                                    0.001019
# JOHNSON & JOHNSON                                    0.001143
# EMERGENT BIOSOLUTIONS INC.                           0.003220
# ...                                                       ...
# CYTOMX THERAPEUTICS, INC.                            0.004396
# VERASTEM, INC.                                       0.004636
# PROPHASE LABS, INC.                                  0.001871
# INTRA-CELLULAR THERAPIES, INC.                       0.005212
# BIOMARIN PHARMACEUTICAL INC                          0.000924
#
# name                            ONCOMED PHARMACEUTICALS INC  \
# name
# BRISTOL MYERS SQUIBB CO                            0.001536
# ACHAOGEN INC                                       0.053370
# MERCK & CO., INC.                                  0.004300
# JOHNSON & JOHNSON                                  0.001576
# EMERGENT BIOSOLUTIONS INC.                         0.017459
# ...                                                     ...
# CYTOMX THERAPEUTICS, INC.                          0.027945
# VERASTEM, INC.                                     0.031128
# PROPHASE LABS, INC.                                0.005278
# INTRA-CELLULAR THERAPIES, INC.                     0.026991
# BIOMARIN PHARMACEUTICAL INC                        0.006542
#
# name                            AMICUS THERAPEUTICS INC  \
# name
# BRISTOL MYERS SQUIBB CO                        0.001310
# ACHAOGEN INC                                   0.019979
# MERCK & CO., INC.                              0.001423
# JOHNSON & JOHNSON                              0.000605
# EMERGENT BIOSOLUTIONS INC.                     0.006731
# ...                                                 ...
# CYTOMX THERAPEUTICS, INC.                      0.009687
# VERASTEM, INC.                                 0.009352
# PROPHASE LABS, INC.                            0.002045
# INTRA-CELLULAR THERAPIES, INC.                 0.008177
# BIOMARIN PHARMACEUTICAL INC                    0.003777
#
# name                            PAIN THERAPEUTICS INC  \
# name
# BRISTOL MYERS SQUIBB CO                      0.000000
# ACHAOGEN INC                                 0.031805
# MERCK & CO., INC.                            0.002773
# JOHNSON & JOHNSON                            0.000507
# EMERGENT BIOSOLUTIONS INC.                   0.015569
# ...                                               ...
# CYTOMX THERAPEUTICS, INC.                    0.029488
# VERASTEM, INC.                               0.037722
# PROPHASE LABS, INC.                          0.002522
# INTRA-CELLULAR THERAPIES, INC.               0.029497
# BIOMARIN PHARMACEUTICAL INC                  0.014959
#
# name                            CYTOMX THERAPEUTICS, INC.  VERASTEM, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                          0.001483        0.001907
# ACHAOGEN INC                                     0.034901        0.036727
# MERCK & CO., INC.                                0.002006        0.005914
# JOHNSON & JOHNSON                                0.000678        0.001012
# EMERGENT BIOSOLUTIONS INC.                       0.012530        0.021444
# ...                                                   ...             ...
# CYTOMX THERAPEUTICS, INC.                        0.024791        0.023975
# VERASTEM, INC.                                   0.023975        0.067026
# PROPHASE LABS, INC.                              0.002726        0.007469
# INTRA-CELLULAR THERAPIES, INC.                   0.018467        0.022733
# BIOMARIN PHARMACEUTICAL INC                      0.006905        0.010273
#
# name                            PROPHASE LABS, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                    0.000698
# ACHAOGEN INC                               0.012580
# MERCK & CO., INC.                          0.002124
# JOHNSON & JOHNSON                          0.000693
# EMERGENT BIOSOLUTIONS INC.                 0.005760
# ...                                             ...
# CYTOMX THERAPEUTICS, INC.                  0.002726
# VERASTEM, INC.                             0.007469
# PROPHASE LABS, INC.                        0.009482
# INTRA-CELLULAR THERAPIES, INC.             0.004140
# BIOMARIN PHARMACEUTICAL INC                0.000831
#
# name                            INTRA-CELLULAR THERAPIES, INC.  \
# name
# BRISTOL MYERS SQUIBB CO                               0.000000
# ACHAOGEN INC                                          0.034174
# MERCK & CO., INC.                                     0.003920
# JOHNSON & JOHNSON                                     0.000671
# EMERGENT BIOSOLUTIONS INC.                            0.011419
# ...                                                        ...
# CYTOMX THERAPEUTICS, INC.                             0.018467
# VERASTEM, INC.                                        0.022733
# PROPHASE LABS, INC.                                   0.004140
# INTRA-CELLULAR THERAPIES, INC.                        0.047693
# BIOMARIN PHARMACEUTICAL INC                           0.004807
#
# name                            BIOMARIN PHARMACEUTICAL INC
# name
# BRISTOL MYERS SQUIBB CO                            0.000452
# ACHAOGEN INC                                       0.008162
# MERCK & CO., INC.                                  0.001041
# JOHNSON & JOHNSON                                  0.000146
# EMERGENT BIOSOLUTIONS INC.                         0.004490
# ...                                                     ...
# CYTOMX THERAPEUTICS, INC.                          0.006905
# VERASTEM, INC.                                     0.010273
# PROPHASE LABS, INC.                                0.000831
# INTRA-CELLULAR THERAPIES, INC.                     0.004807
# BIOMARIN PHARMACEUTICAL INC                        0.007078
#
# [124 rows x 124 columns]

# %% [markdown]
# #### Efficient Frontier - Pharmaceutical Preparations

# %%
ef1 = EfficientFrontier(mu_Pharm, cos_sim_cov, weight_bounds=(0, 0.2))

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef1, ax=ax, show_assets=True)

# Find and plot the tangency portfolio
ef2 = EfficientFrontier(mu_Pharm, cos_sim_cov, weight_bounds=(0, 0.2))
# min volatility
ef2.min_volatility()
ret_tangent, std_tangent, _ = ef2.portfolio_performance()
ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r", label="Min Volatility")

# Format
ax.set_title("Efficient Frontier - Pharmaceutical Preparations \n Cosine Similarity Estimates")
ax.legend()
plt.tight_layout()
plt.savefig('images/Efficient_Frontier_Cos_Sim_Pharmaceutical_Preparations.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ![Efficient_Frontier_Cos_Sim_Pharmaceutical_Preparations.png](images/Efficient_Frontier_Cos_Sim_Pharmaceutical_Preparations.png)

# %% [markdown]
# ##### Min Volatility Portfolio

# %% [markdown]
# ###### Performance

# %%
ef2.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 1.2%
# Annual volatility: 2.6%
# Sharpe Ratio: -0.32

# %% [markdown]
# ###### Weights

# %%
companies = []
weights = []
for company, weight in ef2.clean_weights().items():
    if weight != 0:
        companies.append(company)
        weights.append(weight)
        
dic = {'Company_Name':companies,'Weight':weights}
min_vol = pd.DataFrame(dic)
min_vol = pd.DataFrame(dic)
min_vol.to_csv("data/min_vol_cos_sim_Pharmaceutical_Preparations.csv", index = False)

# %%
pd.read_csv("data/min_vol_cos_sim_Pharmaceutical_Preparations.csv")
# Out:
#                       Company_Name   Weight
# 0          BRISTOL MYERS SQUIBB CO  0.03719
# 1                MERCK & CO., INC.  0.13753
# 2                JOHNSON & JOHNSON  0.18756
# 3                       ARQULE INC  0.00068
# 4      FIVE PRIME THERAPEUTICS INC  0.01782
# 5                   PERRIGO CO PLC  0.01497
# 6                      ZOETIS INC.  0.20000
# 7                       XENCOR INC  0.02108
# 8                       PFIZER INC  0.20000
# 9     PACIRA PHARMACEUTICALS, INC.  0.01883
# 10   HERON THERAPEUTICS, INC. /DE/  0.00906
# 11                  LILLY ELI & CO  0.03562
# 12  BIOSPECIFICS TECHNOLOGIES CORP  0.07394
# 13     BIOMARIN PHARMACEUTICAL INC  0.04572

# %% [markdown]
# ### Results for the Other 4 Industries

# %%
SIC_list = [7372, 1311, 6798, 6022]
SIC_desc = ['Prepackaged Software (mass reproduction of software)', 'Crude Petroleum and Natural Gas', 
           'Real Estate Investment Trusts', 'State Commercial Banks (commercial banking)']

# %% [markdown]
# #### Prepackaged Software (mass reproduction of software)

# %%
SIC = SIC_list[0]
    
industry_name = SIC_desc[SIC_list.index(SIC)]
    
# get the names of the companies in the other industries
Companies = df[df.SIC == SIC]
Company_list = Companies.index

# get the companies name that match return data and business description data
SET = (set(Company_list) & set(r_selected.index))
LIST = [*SET, ]

mu_sample = mu[LIST]
# get the outliers
outlier = mu_sample[mu_sample>1].index
mu_sample = mu_sample.drop(outlier)
LIST = mu_sample.index

tmp = cov[LIST].T
cov_sample = tmp[LIST]

tmp = cosine_sim[LIST].T
tmp = tmp[~tmp.index.duplicated(keep="first")]
industry_cos_sim = tmp[LIST].T
industry_cos_sim = industry_cos_sim[~industry_cos_sim.index.duplicated(keep="first")]

sd = pd.DataFrame(np.sqrt(np.diag(np.diagonal(cov_sample))))
sd = sd.set_index(cov_sample.index)
sd.columns = cov_sample.index
cos_sim_cov = pd.DataFrame((np.dot(np.dot(sd, industry_cos_sim),sd)))

# perform minimum variance analysis
ef1 = EfficientFrontier(mu_sample, cos_sim_cov, weight_bounds=(0, 0.2))

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef1, ax=ax, show_assets=True)

# Find and plot the tangency portfolio
ef2 = EfficientFrontier(mu_sample, cos_sim_cov, weight_bounds=(0, 0.2))
# min volatility
ef2.min_volatility()
ret_tangent, std_tangent, _ = ef2.portfolio_performance()
ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r", label="Min Volatility")

# Format
ax.set_title("Efficient Frontier - %s \n Cosine Similarity Estimates" %industry_name)
ax.legend()
plt.tight_layout()
plt.savefig('images/Efficient_Frontier_Cosine_Similarity_Estimates_Prepackaged_Software.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ![Efficient_Frontier_Cosine_Similarity_Estimates_Prepackaged_Software.png](images/Efficient_Frontier_Cosine_Similarity_Estimates_Prepackaged_Software.png)

# %% [markdown]
# ##### Min Volatility Portfolio

# %% [markdown]
# ###### Performance

# %%
ef2.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 1.1%
# Annual volatility: 2.9%
# Sharpe Ratio: -0.30

# %% [markdown]
# ###### Weights

# %%
companies = []
weights = []
for company, weight in ef2.clean_weights().items():
    if weight != 0:
        companies.append(company)
        weights.append(weight)
        
dic = {'Company_Name':companies,'Weight':weights}
min_vol = pd.DataFrame(dic)
min_vol.to_csv("data/min_vol_cos_sim_Prepackaged_Software.csv", index = False)

# %%
pd.read_csv("data/min_vol_cos_sim_Prepackaged_Software.csv")
# Out:
#                    Company_Name   Weight
# 0     NATIONAL INSTRUMENTS CORP  0.09372
# 1                     ANSYS INC  0.15390
# 2             Q2 HOLDINGS, INC.  0.06190
# 3   NUANCE COMMUNICATIONS, INC.  0.05947
# 4                   ZEDGE, INC.  0.00391
# 5                  REALPAGE INC  0.02937
# 6            INTELLICHECK, INC.  0.00938
# 7   ULTIMATE SOFTWARE GROUP INC  0.10350
# 8           ACI WORLDWIDE, INC.  0.04754
# 9      ALARM.COM HOLDINGS, INC.  0.01069
# 10               AWARE INC /MA/  0.02316
# 11                  ORACLE CORP  0.16315
# 12           BLACK KNIGHT, INC.  0.20000
# 13              GSE SYSTEMS INC  0.04031

# %% [markdown]
# #### Crude Petroleum and Natural Gas
# When we conduct the same analysis, there is no weight shown. Efficient frontier cannot be found.

# %% [markdown]
# #### Real Estate Investment Trusts

# %%
SIC = SIC_list[2]
    
industry_name = SIC_desc[SIC_list.index(SIC)]
    
# get the names of the companies in the other industries
Companies = df[df.SIC == SIC]
Company_list = Companies.index

# get the companies name that match return data and business description data
SET = (set(Company_list) & set(r_selected.index))
LIST = [*SET, ]

mu_sample = mu[LIST]
# get the outliers
outlier = mu_sample[mu_sample>1].index
mu_sample = mu_sample.drop(outlier)
LIST = mu_sample.index

tmp = cov[LIST].T
cov_sample = tmp[LIST]

tmp = cosine_sim[LIST].T
tmp = tmp[~tmp.index.duplicated(keep="first")]
industry_cos_sim = tmp[LIST].T
industry_cos_sim = industry_cos_sim[~industry_cos_sim.index.duplicated(keep="first")]

sd = pd.DataFrame(np.sqrt(np.diag(np.diagonal(cov_sample))))
sd = sd.set_index(cov_sample.index)
sd.columns = cov_sample.index
cos_sim_cov = pd.DataFrame((np.dot(np.dot(sd, industry_cos_sim),sd)))

# perform minimum variance analysis
ef1 = EfficientFrontier(mu_sample, cos_sim_cov, weight_bounds=(0, 0.2))

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef1, ax=ax, show_assets=True)

# Find and plot the tangency portfolio
ef2 = EfficientFrontier(mu_sample, cos_sim_cov, weight_bounds=(0, 0.2))
# min volatility
ef2.min_volatility()
ret_tangent, std_tangent, _ = ef2.portfolio_performance()
ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r", label="Min Volatility")

# Format
ax.set_title("Efficient Frontier - %s \n Cosine Similarity Estimates" %industry_name)
ax.legend()
plt.tight_layout()
plt.savefig('images/Efficient_Frontier_Cosine_Similarity_Estimates_Real_Estate_Investment_Trusts.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ![Efficient_Frontier_Cosine_Similarity_Estimates_Real_Estate_Investment_Trusts.png](images/Efficient_Frontier_Cosine_Similarity_Estimates_Real_Estate_Investment_Trusts.png)

# %% [markdown]
# ##### Min Volatility Portfolio

# %% [markdown]
# ###### Performance

# %%
ef2.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 0.6%
# Annual volatility: 1.7%
# Sharpe Ratio: -0.81

# %% [markdown]
# ###### Weights

# %%
companies = []
weights = []
for company, weight in ef2.clean_weights().items():
    if weight != 0:
        companies.append(company)
        weights.append(weight)
        
dic = {'Company_Name':companies,'Weight':weights}
min_vol = pd.DataFrame(dic)
min_vol.to_csv("data/min_vol_cos_sim_Real_Estate_Investment_Trusts.csv", index = False)

# %%
pd.read_csv("data/min_vol_cos_sim_Real_Estate_Investment_Trusts.csv")
# Out:
#                          Company_Name   Weight
# 0                      ALEXANDERS INC  0.01487
# 1                        RAYONIER INC  0.00876
# 2            EASTGROUP PROPERTIES INC  0.01785
# 3                         EQUINIX INC  0.07068
# 4                 MFA FINANCIAL, INC.  0.05101
# 5   HEALTHCARE TRUST OF AMERICA, INC.  0.02052
# 6                      PUBLIC STORAGE  0.06339
# 7                  LTC PROPERTIES INC  0.00036
# 8       ANNALY CAPITAL MANAGEMENT INC  0.05094
# 9   GAMING & LEISURE PROPERTIES, INC.  0.06734
# 10      STARWOOD PROPERTY TRUST, INC.  0.01851
# 11                EQUITY COMMONWEALTH  0.16327
# 12       HMG COURTLAND PROPERTIES INC  0.03187
# 13                SUN COMMUNITIES INC  0.14907
# 14                   GREAT AJAX CORP.  0.13806
# 15           HIGHWOODS PROPERTIES INC  0.05347
# 16                   DUKE REALTY CORP  0.05369
# 17    CROWN CASTLE INTERNATIONAL CORP  0.02634

# %% [markdown]
# #### State Commercial Banks (commercial banking)

# %%
SIC = SIC_list[3]
    
industry_name = SIC_desc[SIC_list.index(SIC)]
    
# get the names of the companies in the other industries
Companies = df[df.SIC == SIC]
Company_list = Companies.index

# get the companies name that match return data and business description data
SET = (set(Company_list) & set(r_selected.index))
LIST = [*SET, ]

mu_sample = mu[LIST]
# get the outliers
outlier = mu_sample[mu_sample>1].index
mu_sample = mu_sample.drop(outlier)
LIST = mu_sample.index

tmp = cov[LIST].T
cov_sample = tmp[LIST]

tmp = cosine_sim[LIST].T
tmp = tmp[~tmp.index.duplicated(keep="first")]
industry_cos_sim = tmp[LIST].T
industry_cos_sim = industry_cos_sim[~industry_cos_sim.index.duplicated(keep="first")]

sd = pd.DataFrame(np.sqrt(np.diag(np.diagonal(cov_sample))))
sd = sd.set_index(cov_sample.index)
sd.columns = cov_sample.index
cos_sim_cov = pd.DataFrame((np.dot(np.dot(sd, industry_cos_sim),sd)))

# perform minimum variance analysis
ef1 = EfficientFrontier(mu_sample, cos_sim_cov, weight_bounds=(0, 0.2))

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef1, ax=ax, show_assets=True)

# Find and plot the tangency portfolio
ef2 = EfficientFrontier(mu_sample, cos_sim_cov, weight_bounds=(0, 0.2))
# min volatility
ef2.min_volatility()
ret_tangent, std_tangent, _ = ef2.portfolio_performance()
ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r", label="Min Volatility")

# Format
ax.set_title("Efficient Frontier - %s \n Cosine Similarity Estimates" %industry_name)
ax.legend()
plt.tight_layout()
plt.savefig('images/Efficient_Frontier_Cosine_Similarity_Estimates_State_Commercial_Banks.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ![Efficient_Frontier_Cosine_Similarity_Estimates_State_Commercial_Banks.png](images/Efficient_Frontier_Cosine_Similarity_Estimates_State_Commercial_Banks.png)

# %% [markdown]
# ##### Min Volatility Portfolio

# %% [markdown]
# ###### Performance

# %%
ef2.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 1.1%
# Annual volatility: 2.2%
# Sharpe Ratio: -0.38

# %% [markdown]
# ###### Weights

# %%
companies = []
weights = []
for company, weight in ef2.clean_weights().items():
    if weight != 0:
        companies.append(company)
        weights.append(weight)
        
dic = {'Company_Name':companies,'Weight':weights}
min_vol = pd.DataFrame(dic)
min_vol.to_csv("data/min_vol_cos_sim_State_Commercial_Banks.csv", index = False)

# %%
pd.read_csv("data/min_vol_cos_sim_State_Commercial_Banks.csv")
# Out:
#                           Company_Name   Weight
# 0           INDEPENDENT BANK CORP /MI/  0.09540
# 1                EAST WEST BANCORP INC  0.08342
# 2                          BANNER CORP  0.20000
# 3                   HOWARD BANCORP INC  0.02931
# 4   ENTERPRISE FINANCIAL SERVICES CORP  0.07078
# 5                  BANK OF HAWAII CORP  0.04935
# 6                INVESTAR HOLDING CORP  0.16789
# 7             CITIZENS & NORTHERN CORP  0.11305
# 8          CB FINANCIAL SERVICES, INC.  0.02883
# 9               UNITY BANCORP INC /NJ/  0.01179
# 10                     S&T BANCORP INC  0.05201
# 11        BANK OF NEW YORK MELLON CORP  0.09816
